# %% [markdown]
# # create a network graph of flight data

# %%
import sqlalchemy as sa
import pandas as pd
import pprint
from datetime import datetime
import time
from datetime import timedelta
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx
import math
from networkx.drawing.nx_agraph import graphviz_layout

CONNECTION_STRING_SQLALCHEMY = 'postgresql://localhost/FlightData'
con = sa.create_engine(CONNECTION_STRING_SQLALCHEMY)

# %%
# helper functions 
def runQuery(sql): 
    conn = sa.create_engine(CONNECTION_STRING_SQLALCHEMY)
    retVal = None
    result = pd.read_sql(sql, conn,params=None)
    retVal = result
    return retVal

def setInEdges(collection, source):
    for edge in collection: 
        # create a tuple of (source, target)
        edgeTup = (source, edge.text)
        edgeList.append(edgeTup)
        #citeSources.append(source)
        #citeTargets.append(edge.text)

def setOutEdges(collection, target):
    for edge in collection:
        edgeTup = (edge.text, target)
        edgeList.append(edgeTup)
        #citeSources.append(edge.text)
        #citeTargets.append(target)

# %% [markdown]
# ## helpers related to data load

# %%
def loadAirports(G, airports):
    # create a node list from airports 
    for index, airport in airports.iterrows():
        airportcode = airport['iata']
        name = airport['name']
        long = airport['latitude']
        lat=airport['longitude']
        totalflights=airport['totalflights']
        numberofdelays=airport['numberofdelays']
        delaypercentage=airport['delaypercentage']
        carrierdelay=airport['carrierdelay']
        weatherdelay=airport['weatherdelay']
        nasdelay=airport['nasdelay']
        securitydelay=airport['securitydelay']
        lateaircraftdelay=airport['lateaircraftdelay']
        G.add_node(airportcode, code=airportcode, name=name, long=long,lat=lat,totalflights=totalflights, 
                   numberofdelays=numberofdelays, delaypercentage=delaypercentage,
                   carrierdelay=carrierdelay, weatherdelay=weatherdelay,nasdelay=nasdelay,
                   securitydelay=securitydelay, lateaircraftdelay=lateaircraftdelay)
    return G

def loadRoutes(G, routes):
    # load the edges 
    for index, route in routes.iterrows():
        G.add_edge(route["origin"], route["destination"], weight=route["count"],
                   arrivaldelaymins=route["total_arrival_delay_minutes"], numofdelays=route["number_of_delays"],
                  delaypercentage=route["delaypercentage"])
    return G
    
def getOverviewGraph(airports, routes):
    
    print("start graph load")
    
    # initiate NX objects 
    G=nx.MultiDiGraph()
    nodes = []
    
    print("creating airport nodes")
    G = loadAirports(G, airports)
    print("Loading edges")
    G = loadRoutes(G, routes)
    
    # network summary 
    print("number of nodes:", len(G))
    print("number of edges:", nx.number_of_edges(G))
    print("Graph Density:", nx.density(G))

    isolatedAirports = nx.isolates(G) # airports with no flight data?
    print("Total isolated airports found:", len(isolatedAirports))

    G.remove_nodes_from(isolatedAirports)

    print("number of nodes post isolated:", len(G))
    print("number of edges post isolated:", nx.number_of_edges(G))
    print("Graph Density post isolated:", nx.density(G))
    
    print("end graph load")
    
    return G

# %% [markdown]
# ## load the edges
# ### possible combinations
# * load edges from flights that are delayed only?
# - load by flight number (capture the unique flights between airports). Repeat flighnts reflected by edge weight.
# - load edges by carrier (e.g. AA, Delta)
# - load by all flights (capture any flights between two airports). Repeat flights reflected by edge weight.
# - Load all flights and save aggregated delay in the nodes (which airport has the most amount of delay?)
# - load all flights and capture the total number of delays as opposed to delay in minutes.
# - filter by month.
# - filter daily?
# - filter by year?

# %%
# pandas load data files 

airports = pd.read_csv('data/airline_stats_network_2008.csv')
routes = pd.read_csv('data/flightdata2008.csv')

# %%
# load the network
G = getOverviewGraph(airports=airports, routes=routes)
# Out:
# start graph load
# creating airport nodes
# Loading edges
# number of nodes: 3376
# number of edges: 5112
# Graph Density: 0.0004486571879936809
# Total isolated airports found: 3073
# number of nodes post isolated: 303
# number of edges post isolated: 5112
# Graph Density post isolated: 0.055865189167923414
# end graph load

# %% [markdown]
# ## carry out centrality calculations

# %%
#G = nx.convert_node_labels_to_integers(G)

# %%
bb = nx.betweenness_centrality(G, weight="weight")
outdeg = nx.out_degree_centrality(G)
indeg = nx.in_degree_centrality(G)
#eigen = nx.eigenvector_centrality(G)
isinstance(bb, dict)
isinstance(outdeg, dict)
isinstance(indeg, dict)
#bb
# Out:
# True

# %%
for airport in (sorted(bb,key=bb.get, reverse=True)):
    print(airport, bb[airport])
# Out:
# ATL 0.20952914518675297
# SLC 0.11620390070112355
# DFW 0.10728373636220448
# MSP 0.10246774639976602
# ORD 0.08818055269441359
# ANC 0.07210662358084305
# DTW 0.06876935137212326
# DEN 0.06515843513538519
# IAH 0.059574650373151516
# LAX 0.04913096877988335
# SFO 0.045973263655420565
# CVG 0.03935605915038366
# SEA 0.03833730171145242
# PHX 0.03209772737994136
# LAS 0.019531435564660353
# JNU 0.01831326887987506
# MCO 0.017215400158154592
# EWR 0.01649355928996716
# CLT 0.016352049443426712
# MEM 0.011102657032244159
# JFK 0.010548467789107683
# PDX 0.009312287579390895
# MKE 0.008346809648940256
# IAD 0.007696964652453864
# LGA 0.006958580279886503
# KTN 0.0064578703805563496
# FLL 0.005396587018072953
# BOS 0.005334885699833588
# HNL 0.005117438740266624
# CLE 0.005078859906523481
# TPA 0.004419449714196751
# FAI 0.003793287194455131
# BWI 0.0037741554830833324
# AUS 0.0037735067731941674
# SAN 0.0034893941065182667
# SMF 0.003488903206837548
# JAX 0.0034564340884064124
# COS 0.0033936974878581083
# DCA 0.0026792730619862237
# ABQ 0.002552799504367757
# MIA 0.0021909564878949423
# MDW 0.0020664703995840264
# OGG 0.0019670661794668892
# PHL 0.0018895758539852763
# SAT 0.0018497268238894294
# CDV 0.0017185602694652592
# MCI 0.0016825140952705549
# HOU 0.0015535761128212364
# FNT 0.001419331000158381
# STL 0.0013176358793383655
# PIT 0.0011966106225061457
# BNA 0.0010607448691271756
# GRR 0.0008136393307740611
# ONT 0.0007942020276986169
# SNA 0.0007358060364905344
# OAK 0.0007074869559871619
# RDU 0.000666168140476291
# BZN 0.0006471544812097887
# SJC 0.000614537708934078
# RSW 0.0005899670525989125
# TUL 0.0005607914881369557
# KOA 0.000533169348073191
# GRB 0.00052686378042857
# OKC 0.00046780999173069704
# XNA 0.00045146455107926837
# ELP 0.00044275259005429067
# PBI 0.00043851405600462047
# DAL 0.0004097602661291563
# DSM 0.00040851872169332833
# MSY 0.00040753294586361465
# TUS 0.00039905021767529345
# YUM 0.00033546528593176786
# BHM 0.0003287580445558555
# IND 0.000309892044452563
# SCC 0.00030007856591317424
# ACV 0.00026901619511147126
# BDL 0.0002297313160869164
# LIT 0.00022807623435220386
# RNO 0.0002122446202806759
# LGB 0.00020911054251824572
# MFR 0.00014923013032370138
# SJU 0.00013041521627667448
# BOI 0.00012033648270648211
# SDF 0.00011181026373291013
# PSG 0.00010964188540039454
# PIA 0.00010908481142609666
# CMH 0.00010905535524396907
# ORF 0.00010132932245690813
# OMA 7.879369717170795e-05
# MSN 7.097193033196619e-05
# FAR 6.337855290989078e-05
# YAK 5.647107141023667e-05
# CMI 5.5543684621520485e-05
# GEG 5.365424127388261e-05
# FAT 5.071827235444987e-05
# ASE 4.805769375709377e-05
# SBA 3.80889552753502e-05
# FSD 3.74002203633144e-05
# AMA 2.8965054200956895e-05
# JAN 2.8810117055476305e-05
# HPN 2.1370011007774035e-05
# MAF 1.908924912738126e-05
# AZO 1.7988166861476345e-05
# LBB 1.7669783570358138e-05
# LNK 1.702513748453332e-05
# GTF 1.702077206466549e-05
# BUF 1.5642741549332617e-05
# GJT 1.2748768513587919e-05
# BTV 1.2057988110469155e-05
# LEX 1.200498137102262e-05
# WRG 1.100085806692922e-05
# MRY 1.0915476838577051e-05
# BUR 9.89287509531947e-06
# HSV 7.999424537953443e-06
# SRQ 7.960418605645327e-06
# CAK 7.585186952322513e-06
# SBP 7.478734601803139e-06
# MOD 6.595342022884682e-06
# HDN 6.543900661172316e-06
# ISP 5.726473987923994e-06
# EGE 5.720240163730267e-06
# ICT 5.627117493572606e-06
# BRW 5.50042903346461e-06
# PVD 5.385110121721707e-06
# ALB 4.643810470283535e-06
# MHT 4.497548165196528e-06
# SPI 4.354864605616066e-06
# RIC 3.7018737268889796e-06
# TYS 3.0288965395546323e-06
# STT 2.7523416351234447e-06
# HRL 1.998458086861505e-06
# DAY 1.603852016360582e-06
# GSO 1.4785431467689716e-06
# SAV 1.452350627561997e-06
# CRP 1.419465557023125e-06
# SWF 1.395036349067111e-06
# SGF 1.3751072583661525e-06
# BGR 1.2865410281662985e-06
# MKG 1.2223175629921355e-06
# SYR 9.504036983434613e-07
# CAE 9.285002434225106e-07
# CHS 9.285002434225106e-07
# GSP 9.285002434225106e-07
# PWM 8.055231166123346e-07
# ROC 8.055231166123346e-07
# DAB 7.9975403166836e-07
# TLH 5.946409765907687e-07
# BFL 4.782981768230095e-07
# MYR 4.448876424125787e-07
# LIH 4.400343226771688e-07
# ACK 3.6980285592219693e-07
# BQN 3.6980285592219693e-07
# PSE 3.6980285592219693e-07
# MDT 2.1570309935155332e-07
# ROA 2.1570309935155332e-07
# ABE 0.0
# ABI 0.0
# ABY 0.0
# ACT 0.0
# ACY 0.0
# ADK 0.0
# ADQ 0.0
# AEX 0.0
# AGS 0.0
# AKN 0.0
# ALO 0.0
# ATW 0.0
# AVL 0.0
# AVP 0.0
# BET 0.0
# BGM 0.0
# BIL 0.0
# BIS 0.0
# BJI 0.0
# BLI 0.0
# BMI 0.0
# BPT 0.0
# BQK 0.0
# BRO 0.0
# BTM 0.0
# BTR 0.0
# CDC 0.0
# CEC 0.0
# CHA 0.0
# CHO 0.0
# CIC 0.0
# CID 0.0
# CLD 0.0
# CLL 0.0
# CMX 0.0
# COD 0.0
# CPR 0.0
# CRW 0.0
# CSG 0.0
# CWA 0.0
# DBQ 0.0
# DHN 0.0
# DLG 0.0
# DLH 0.0
# DRO 0.0
# EKO 0.0
# ELM 0.0
# ERI 0.0
# EUG 0.0
# EVV 0.0
# EWN 0.0
# EYW 0.0
# FAY 0.0
# FCA 0.0
# FLG 0.0
# FLO 0.0
# FSM 0.0
# FWA 0.0
# GCC 0.0
# GFK 0.0
# GGG 0.0
# GNV 0.0
# GPT 0.0
# GRK 0.0
# GST 0.0
# GTR 0.0
# GUC 0.0
# HHH 0.0
# HLN 0.0
# HTS 0.0
# IDA 0.0
# ILM 0.0
# IPL 0.0
# ITH 0.0
# ITO 0.0
# IYK 0.0
# JAC 0.0
# LAN 0.0
# LAW 0.0
# LCH 0.0
# LFT 0.0
# LMT 0.0
# LRD 0.0
# LSE 0.0
# LWB 0.0
# LWS 0.0
# LYH 0.0
# MBS 0.0
# MCN 0.0
# MEI 0.0
# MFE 0.0
# MGM 0.0
# MLB 0.0
# MLI 0.0
# MLU 0.0
# MOB 0.0
# MOT 0.0
# MQT 0.0
# MSO 0.0
# MTJ 0.0
# OAJ 0.0
# OME 0.0
# OTH 0.0
# OTZ 0.0
# OXR 0.0
# PFN 0.0
# PHF 0.0
# PIH 0.0
# PIR 0.0
# PLN 0.0
# PMD 0.0
# PNS 0.0
# PSC 0.0
# PSP 0.0
# PUB 0.0
# RAP 0.0
# RDD 0.0
# RDM 0.0
# RFD 0.0
# RHI 0.0
# RKS 0.0
# ROW 0.0
# RST 0.0
# SBN 0.0
# SCE 0.0
# SGU 0.0
# SHV 0.0
# SIT 0.0
# SJT 0.0
# SLE 0.0
# SMX 0.0
# SPS 0.0
# STX 0.0
# SUN 0.0
# SUX 0.0
# TEX 0.0
# TOL 0.0
# TRI 0.0
# TUP 0.0
# TVC 0.0
# TWF 0.0
# TXK 0.0
# TYR 0.0
# VLD 0.0
# VPS 0.0
# WYS 0.0
# YKM 0.0
# INL 0.0

# %%
nx.set_node_attributes(G=G,values=bb,name="betweenness")
nx.set_node_attributes(G=G,values=outdeg,name="outdegree")
nx.set_node_attributes(G=G,values=indeg,name="indegree")

# %%
between = nx.get_node_attributes(G, 'betweenness')
print(between['ATL'])
between = nx.get_node_attributes(G, 'outdegree')
print(between['ATL'])
between = nx.get_node_attributes(G, 'indegree')
print(between['ATL'])
# Out:
# 0.20952914518675297
# 0.5695364238410596
# 0.5728476821192053

# %%
for origin,destination,attr in G.edges_iter(data=True):
    print(attr)
#for airport,attr in G.nodes(data=True):
#   print(attr)
# Out:
# {'weight': 853, 'arrivaldelaymins': 9643, 'numofdelays': 183, 'delaypercentage': 21}
# {'weight': 805, 'arrivaldelaymins': 672, 'numofdelays': 87, 'delaypercentage': 10}
# {'weight': 465, 'arrivaldelaymins': -1333, 'numofdelays': 53, 'delaypercentage': 11}
# {'weight': 247, 'arrivaldelaymins': -1092, 'numofdelays': 16, 'delaypercentage': 6}
# {'weight': 997, 'arrivaldelaymins': 5168, 'numofdelays': 152, 'delaypercentage': 15}
# {'weight': 3, 'arrivaldelaymins': 73, 'numofdelays': 3, 'delaypercentage': 100}
# {'weight': 9, 'arrivaldelaymins': 962, 'numofdelays': 8, 'delaypercentage': 88}
# {'weight': 1425, 'arrivaldelaymins': 21810, 'numofdelays': 364, 'delaypercentage': 25}
# {'weight': 2, 'arrivaldelaymins': 34, 'numofdelays': 1, 'delaypercentage': 50}
# {'weight': 2660, 'arrivaldelaymins': 13168, 'numofdelays': 293, 'delaypercentage': 11}
# {'weight': 368, 'arrivaldelaymins': 4549, 'numofdelays': 103, 'delaypercentage': 27}
# {'weight': 1067, 'arrivaldelaymins': 2029, 'numofdelays': 129, 'delaypercentage': 12}
# {'weight': 433, 'arrivaldelaymins': 1364, 'numofdelays': 69, 'delaypercentage': 15}
# {'weight': 546, 'arrivaldelaymins': 376, 'numofdelays': 72, 'delaypercentage': 13}
# {'weight': 12, 'arrivaldelaymins': -79, 'numofdelays': 1, 'delaypercentage': 8}
# {'weight': 260, 'arrivaldelaymins': 3, 'numofdelays': 32, 'delaypercentage': 12}
# {'weight': 3078, 'arrivaldelaymins': 12253, 'numofdelays': 469, 'delaypercentage': 15}
# {'weight': 4318, 'arrivaldelaymins': 10932, 'numofdelays': 596, 'delaypercentage': 13}
# {'weight': 2888, 'arrivaldelaymins': 17734, 'numofdelays': 458, 'delaypercentage': 15}
# {'weight': 799, 'arrivaldelaymins': 7255, 'numofdelays': 154, 'delaypercentage': 19}
# {'weight': 167, 'arrivaldelaymins': -260, 'numofdelays': 28, 'delaypercentage': 16}
# {'weight': 1011, 'arrivaldelaymins': 3462, 'numofdelays': 158, 'delaypercentage': 15}
# {'weight': 365, 'arrivaldelaymins': -1257, 'numofdelays': 43, 'delaypercentage': 11}
# {'weight': 2261, 'arrivaldelaymins': 17042, 'numofdelays': 381, 'delaypercentage': 16}
# {'weight': 2402, 'arrivaldelaymins': 15706, 'numofdelays': 435, 'delaypercentage': 18}
# {'weight': 2395, 'arrivaldelaymins': 21885, 'numofdelays': 568, 'delaypercentage': 23}
# {'weight': 366, 'arrivaldelaymins': 1305, 'numofdelays': 55, 'delaypercentage': 15}
# {'weight': 367, 'arrivaldelaymins': 5286, 'numofdelays': 111, 'delaypercentage': 30}
# {'weight': 670, 'arrivaldelaymins': 2038, 'numofdelays': 109, 'delaypercentage': 16}
# {'weight': 730, 'arrivaldelaymins': -1586, 'numofdelays': 81, 'delaypercentage': 11}
# {'weight': 730, 'arrivaldelaymins': -1014, 'numofdelays': 66, 'delaypercentage': 9}
# {'weight': 677, 'arrivaldelaymins': 1216, 'numofdelays': 93, 'delaypercentage': 13}
# {'weight': 1016, 'arrivaldelaymins': 2271, 'numofdelays': 164, 'delaypercentage': 16}
# {'weight': 229, 'arrivaldelaymins': 1779, 'numofdelays': 51, 'delaypercentage': 22}
# {'weight': 446, 'arrivaldelaymins': 2659, 'numofdelays': 68, 'delaypercentage': 15}
# {'weight': 751, 'arrivaldelaymins': 9586, 'numofdelays': 197, 'delaypercentage': 26}
# {'weight': 366, 'arrivaldelaymins': 4432, 'numofdelays': 108, 'delaypercentage': 29}
# {'weight': 5265, 'arrivaldelaymins': 19625, 'numofdelays': 828, 'delaypercentage': 15}
# {'weight': 1034, 'arrivaldelaymins': 5051, 'numofdelays': 179, 'delaypercentage': 17}
# {'weight': 424, 'arrivaldelaymins': 1194, 'numofdelays': 51, 'delaypercentage': 12}
# {'weight': 721, 'arrivaldelaymins': 4851, 'numofdelays': 165, 'delaypercentage': 22}
# {'weight': 530, 'arrivaldelaymins': 69, 'numofdelays': 61, 'delaypercentage': 11}
# {'weight': 2307, 'arrivaldelaymins': 2050, 'numofdelays': 276, 'delaypercentage': 11}
# {'weight': 466, 'arrivaldelaymins': 3196, 'numofdelays': 84, 'delaypercentage': 18}
# {'weight': 366, 'arrivaldelaymins': -3136, 'numofdelays': 16, 'delaypercentage': 4}
# {'weight': 366, 'arrivaldelaymins': 262, 'numofdelays': 48, 'delaypercentage': 13}
# {'weight': 230, 'arrivaldelaymins': 76, 'numofdelays': 30, 'delaypercentage': 13}
# {'weight': 719, 'arrivaldelaymins': 7538, 'numofdelays': 166, 'delaypercentage': 23}
# {'weight': 1095, 'arrivaldelaymins': 12741, 'numofdelays': 224, 'delaypercentage': 20}
# {'weight': 234, 'arrivaldelaymins': 5828, 'numofdelays': 82, 'delaypercentage': 35}
# {'weight': 223, 'arrivaldelaymins': 6157, 'numofdelays': 75, 'delaypercentage': 33}
# {'weight': 1993, 'arrivaldelaymins': 5921, 'numofdelays': 246, 'delaypercentage': 12}
# {'weight': 362, 'arrivaldelaymins': 661, 'numofdelays': 42, 'delaypercentage': 11}
# {'weight': 2343, 'arrivaldelaymins': 50782, 'numofdelays': 734, 'delaypercentage': 31}
# {'weight': 388, 'arrivaldelaymins': -130, 'numofdelays': 26, 'delaypercentage': 6}
# {'weight': 618, 'arrivaldelaymins': 1730, 'numofdelays': 86, 'delaypercentage': 13}
# {'weight': 113, 'arrivaldelaymins': 541, 'numofdelays': 12, 'delaypercentage': 10}
# {'weight': 2, 'arrivaldelaymins': 60, 'numofdelays': 2, 'delaypercentage': 100}
# {'weight': 102, 'arrivaldelaymins': 417, 'numofdelays': 22, 'delaypercentage': 21}
# {'weight': 706, 'arrivaldelaymins': 2448, 'numofdelays': 120, 'delaypercentage': 16}
# {'weight': 983, 'arrivaldelaymins': 14635, 'numofdelays': 248, 'delaypercentage': 25}
# {'weight': 1005, 'arrivaldelaymins': 6601, 'numofdelays': 152, 'delaypercentage': 15}
# {'weight': 342, 'arrivaldelaymins': 2782, 'numofdelays': 67, 'delaypercentage': 19}
# {'weight': 2380, 'arrivaldelaymins': 27694, 'numofdelays': 546, 'delaypercentage': 22}
# {'weight': 16, 'arrivaldelaymins': 141, 'numofdelays': 5, 'delaypercentage': 31}
# {'weight': 7, 'arrivaldelaymins': 131, 'numofdelays': 3, 'delaypercentage': 42}
# {'weight': 78, 'arrivaldelaymins': 1583, 'numofdelays': 32, 'delaypercentage': 41}
# {'weight': 38, 'arrivaldelaymins': 886, 'numofdelays': 21, 'delaypercentage': 55}
# {'weight': 1154, 'arrivaldelaymins': 21037, 'numofdelays': 395, 'delaypercentage': 34}
# {'weight': 1, 'arrivaldelaymins': 71, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 2297, 'arrivaldelaymins': 12749, 'numofdelays': 357, 'delaypercentage': 15}
# {'weight': 1113, 'arrivaldelaymins': 11110, 'numofdelays': 278, 'delaypercentage': 24}
# {'weight': 956, 'arrivaldelaymins': 1480, 'numofdelays': 160, 'delaypercentage': 16}
# {'weight': 914, 'arrivaldelaymins': 2205, 'numofdelays': 129, 'delaypercentage': 14}
# {'weight': 327, 'arrivaldelaymins': -1725, 'numofdelays': 23, 'delaypercentage': 7}
# {'weight': 1013, 'arrivaldelaymins': 6643, 'numofdelays': 195, 'delaypercentage': 19}
# {'weight': 611, 'arrivaldelaymins': 14242, 'numofdelays': 214, 'delaypercentage': 35}
# {'weight': 60, 'arrivaldelaymins': -29, 'numofdelays': 10, 'delaypercentage': 16}
# {'weight': 367, 'arrivaldelaymins': 9917, 'numofdelays': 142, 'delaypercentage': 38}
# {'weight': 366, 'arrivaldelaymins': -405, 'numofdelays': 71, 'delaypercentage': 19}
# {'weight': 1037, 'arrivaldelaymins': 1263, 'numofdelays': 158, 'delaypercentage': 15}
# {'weight': 730, 'arrivaldelaymins': -2464, 'numofdelays': 82, 'delaypercentage': 11}
# {'weight': 57, 'arrivaldelaymins': 218, 'numofdelays': 9, 'delaypercentage': 15}
# {'weight': 1630, 'arrivaldelaymins': 19343, 'numofdelays': 392, 'delaypercentage': 24}
# {'weight': 449, 'arrivaldelaymins': 2150, 'numofdelays': 80, 'delaypercentage': 17}
# {'weight': 391, 'arrivaldelaymins': -2323, 'numofdelays': 33, 'delaypercentage': 8}
# {'weight': 323, 'arrivaldelaymins': 1710, 'numofdelays': 27, 'delaypercentage': 8}
# {'weight': 366, 'arrivaldelaymins': -629, 'numofdelays': 10, 'delaypercentage': 2}
# {'weight': 2669, 'arrivaldelaymins': 12108, 'numofdelays': 365, 'delaypercentage': 13}
# {'weight': 729, 'arrivaldelaymins': 465, 'numofdelays': 95, 'delaypercentage': 13}
# {'weight': 2556, 'arrivaldelaymins': 22301, 'numofdelays': 482, 'delaypercentage': 18}
# {'weight': 809, 'arrivaldelaymins': 5657, 'numofdelays': 121, 'delaypercentage': 14}
# {'weight': 366, 'arrivaldelaymins': 2600, 'numofdelays': 66, 'delaypercentage': 18}
# {'weight': 1, 'arrivaldelaymins': 26, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 102, 'arrivaldelaymins': 774, 'numofdelays': 29, 'delaypercentage': 28}
# {'weight': 706, 'arrivaldelaymins': 907, 'numofdelays': 72, 'delaypercentage': 10}
# {'weight': 116, 'arrivaldelaymins': 1278, 'numofdelays': 35, 'delaypercentage': 30}
# {'weight': 115, 'arrivaldelaymins': 1667, 'numofdelays': 30, 'delaypercentage': 26}
# {'weight': 1035, 'arrivaldelaymins': 5007, 'numofdelays': 172, 'delaypercentage': 16}
# {'weight': 362, 'arrivaldelaymins': 6763, 'numofdelays': 113, 'delaypercentage': 31}
# {'weight': 90, 'arrivaldelaymins': 621, 'numofdelays': 27, 'delaypercentage': 30}
# {'weight': 451, 'arrivaldelaymins': 2022, 'numofdelays': 84, 'delaypercentage': 18}
# {'weight': 153, 'arrivaldelaymins': 2459, 'numofdelays': 48, 'delaypercentage': 31}
# {'weight': 78, 'arrivaldelaymins': -175, 'numofdelays': 7, 'delaypercentage': 8}
# {'weight': 96, 'arrivaldelaymins': 154, 'numofdelays': 14, 'delaypercentage': 14}
# {'weight': 3217, 'arrivaldelaymins': 9587, 'numofdelays': 506, 'delaypercentage': 15}
# {'weight': 236, 'arrivaldelaymins': -1103, 'numofdelays': 45, 'delaypercentage': 19}
# {'weight': 207, 'arrivaldelaymins': 4305, 'numofdelays': 58, 'delaypercentage': 28}
# {'weight': 1163, 'arrivaldelaymins': 8867, 'numofdelays': 241, 'delaypercentage': 20}
# {'weight': 237, 'arrivaldelaymins': 537, 'numofdelays': 47, 'delaypercentage': 19}
# {'weight': 238, 'arrivaldelaymins': -490, 'numofdelays': 36, 'delaypercentage': 15}
# {'weight': 826, 'arrivaldelaymins': 4089, 'numofdelays': 158, 'delaypercentage': 19}
# {'weight': 27, 'arrivaldelaymins': -59, 'numofdelays': 3, 'delaypercentage': 11}
# {'weight': 365, 'arrivaldelaymins': 1626, 'numofdelays': 57, 'delaypercentage': 15}
# {'weight': 561, 'arrivaldelaymins': 35, 'numofdelays': 112, 'delaypercentage': 19}
# {'weight': 725, 'arrivaldelaymins': 2171, 'numofdelays': 101, 'delaypercentage': 13}
# {'weight': 576, 'arrivaldelaymins': -694, 'numofdelays': 78, 'delaypercentage': 13}
# {'weight': 366, 'arrivaldelaymins': 888, 'numofdelays': 71, 'delaypercentage': 19}
# {'weight': 363, 'arrivaldelaymins': 2490, 'numofdelays': 66, 'delaypercentage': 18}
# {'weight': 6257, 'arrivaldelaymins': 10902, 'numofdelays': 1037, 'delaypercentage': 16}
# {'weight': 181, 'arrivaldelaymins': 1622, 'numofdelays': 45, 'delaypercentage': 24}
# {'weight': 478, 'arrivaldelaymins': -1256, 'numofdelays': 40, 'delaypercentage': 8}
# {'weight': 16, 'arrivaldelaymins': 109, 'numofdelays': 4, 'delaypercentage': 25}
# {'weight': 3992, 'arrivaldelaymins': 34888, 'numofdelays': 821, 'delaypercentage': 20}
# {'weight': 334, 'arrivaldelaymins': 4547, 'numofdelays': 107, 'delaypercentage': 32}
# {'weight': 332, 'arrivaldelaymins': 12695, 'numofdelays': 145, 'delaypercentage': 43}
# {'weight': 109, 'arrivaldelaymins': 151, 'numofdelays': 14, 'delaypercentage': 12}
# {'weight': 62, 'arrivaldelaymins': 1985, 'numofdelays': 29, 'delaypercentage': 46}
# {'weight': 459, 'arrivaldelaymins': 4653, 'numofdelays': 106, 'delaypercentage': 23}
# {'weight': 852, 'arrivaldelaymins': 7462, 'numofdelays': 190, 'delaypercentage': 22}
# {'weight': 1064, 'arrivaldelaymins': 12810, 'numofdelays': 285, 'delaypercentage': 26}
# {'weight': 1095, 'arrivaldelaymins': 12036, 'numofdelays': 277, 'delaypercentage': 25}
# {'weight': 113, 'arrivaldelaymins': 1519, 'numofdelays': 24, 'delaypercentage': 21}
# {'weight': 982, 'arrivaldelaymins': 10308, 'numofdelays': 222, 'delaypercentage': 22}
# {'weight': 2381, 'arrivaldelaymins': 26593, 'numofdelays': 563, 'delaypercentage': 23}
# {'weight': 1153, 'arrivaldelaymins': 16602, 'numofdelays': 350, 'delaypercentage': 30}
# {'weight': 115, 'arrivaldelaymins': 2157, 'numofdelays': 37, 'delaypercentage': 32}
# {'weight': 16, 'arrivaldelaymins': 553, 'numofdelays': 7, 'delaypercentage': 43}
# {'weight': 742, 'arrivaldelaymins': 6814, 'numofdelays': 185, 'delaypercentage': 24}
# {'weight': 2255, 'arrivaldelaymins': 31858, 'numofdelays': 665, 'delaypercentage': 29}
# {'weight': 1936, 'arrivaldelaymins': 16593, 'numofdelays': 431, 'delaypercentage': 22}
# {'weight': 584, 'arrivaldelaymins': 7949, 'numofdelays': 171, 'delaypercentage': 29}
# {'weight': 2140, 'arrivaldelaymins': 13322, 'numofdelays': 398, 'delaypercentage': 18}
# {'weight': 270, 'arrivaldelaymins': 5276, 'numofdelays': 91, 'delaypercentage': 33}
# {'weight': 2871, 'arrivaldelaymins': 24817, 'numofdelays': 645, 'delaypercentage': 22}
# {'weight': 2509, 'arrivaldelaymins': 24164, 'numofdelays': 592, 'delaypercentage': 23}
# {'weight': 3096, 'arrivaldelaymins': 27700, 'numofdelays': 684, 'delaypercentage': 22}
# {'weight': 41, 'arrivaldelaymins': 884, 'numofdelays': 19, 'delaypercentage': 46}
# {'weight': 5990, 'arrivaldelaymins': 56384, 'numofdelays': 1415, 'delaypercentage': 23}
# {'weight': 924, 'arrivaldelaymins': 8974, 'numofdelays': 204, 'delaypercentage': 22}
# {'weight': 2665, 'arrivaldelaymins': 36031, 'numofdelays': 721, 'delaypercentage': 27}
# {'weight': 500, 'arrivaldelaymins': 7005, 'numofdelays': 143, 'delaypercentage': 28}
# {'weight': 3578, 'arrivaldelaymins': 29627, 'numofdelays': 771, 'delaypercentage': 21}
# {'weight': 5978, 'arrivaldelaymins': 61157, 'numofdelays': 1345, 'delaypercentage': 22}
# {'weight': 60, 'arrivaldelaymins': 803, 'numofdelays': 16, 'delaypercentage': 26}
# {'weight': 2494, 'arrivaldelaymins': 27543, 'numofdelays': 611, 'delaypercentage': 24}
# {'weight': 3902, 'arrivaldelaymins': 38355, 'numofdelays': 877, 'delaypercentage': 22}
# {'weight': 2082, 'arrivaldelaymins': 21136, 'numofdelays': 504, 'delaypercentage': 24}
# {'weight': 786, 'arrivaldelaymins': 7108, 'numofdelays': 173, 'delaypercentage': 22}
# {'weight': 4492, 'arrivaldelaymins': 42047, 'numofdelays': 932, 'delaypercentage': 20}
# {'weight': 357, 'arrivaldelaymins': 1707, 'numofdelays': 69, 'delaypercentage': 19}
# {'weight': 2865, 'arrivaldelaymins': 32105, 'numofdelays': 732, 'delaypercentage': 25}
# {'weight': 6720, 'arrivaldelaymins': 66099, 'numofdelays': 1676, 'delaypercentage': 24}
# {'weight': 1796, 'arrivaldelaymins': 19275, 'numofdelays': 430, 'delaypercentage': 23}
# {'weight': 589, 'arrivaldelaymins': 10922, 'numofdelays': 212, 'delaypercentage': 35}
# {'weight': 5, 'arrivaldelaymins': -8, 'numofdelays': 1, 'delaypercentage': 20}
# {'weight': 1430, 'arrivaldelaymins': 10831, 'numofdelays': 285, 'delaypercentage': 19}
# {'weight': 1481, 'arrivaldelaymins': 17196, 'numofdelays': 378, 'delaypercentage': 25}
# {'weight': 2810, 'arrivaldelaymins': 32439, 'numofdelays': 635, 'delaypercentage': 22}
# {'weight': 2413, 'arrivaldelaymins': 26748, 'numofdelays': 555, 'delaypercentage': 23}
# {'weight': 4372, 'arrivaldelaymins': 38867, 'numofdelays': 912, 'delaypercentage': 20}
# {'weight': 7289, 'arrivaldelaymins': 55573, 'numofdelays': 1380, 'delaypercentage': 18}
# {'weight': 5726, 'arrivaldelaymins': 48438, 'numofdelays': 1419, 'delaypercentage': 24}
# {'weight': 9847, 'arrivaldelaymins': 105745, 'numofdelays': 2394, 'delaypercentage': 24}
# {'weight': 1397, 'arrivaldelaymins': 16416, 'numofdelays': 351, 'delaypercentage': 25}
# {'weight': 1114, 'arrivaldelaymins': 9752, 'numofdelays': 267, 'delaypercentage': 23}
# {'weight': 5612, 'arrivaldelaymins': 50720, 'numofdelays': 1227, 'delaypercentage': 21}
# {'weight': 110, 'arrivaldelaymins': -126, 'numofdelays': 13, 'delaypercentage': 11}
# {'weight': 575, 'arrivaldelaymins': 6573, 'numofdelays': 140, 'delaypercentage': 24}
# {'weight': 1150, 'arrivaldelaymins': 9280, 'numofdelays': 263, 'delaypercentage': 22}
# {'weight': 791, 'arrivaldelaymins': 4521, 'numofdelays': 149, 'delaypercentage': 18}
# {'weight': 8028, 'arrivaldelaymins': 161095, 'numofdelays': 2701, 'delaypercentage': 33}
# {'weight': 974, 'arrivaldelaymins': 18586, 'numofdelays': 331, 'delaypercentage': 33}
# {'weight': 2173, 'arrivaldelaymins': 27802, 'numofdelays': 532, 'delaypercentage': 24}
# {'weight': 25, 'arrivaldelaymins': 231, 'numofdelays': 6, 'delaypercentage': 24}
# {'weight': 7665, 'arrivaldelaymins': 79542, 'numofdelays': 1839, 'delaypercentage': 23}
# {'weight': 614, 'arrivaldelaymins': 5899, 'numofdelays': 119, 'delaypercentage': 19}
# {'weight': 3132, 'arrivaldelaymins': 26648, 'numofdelays': 702, 'delaypercentage': 22}
# {'weight': 135, 'arrivaldelaymins': 2327, 'numofdelays': 38, 'delaypercentage': 28}
# {'weight': 632, 'arrivaldelaymins': 5400, 'numofdelays': 138, 'delaypercentage': 21}
# {'weight': 1028, 'arrivaldelaymins': 10911, 'numofdelays': 251, 'delaypercentage': 24}
# {'weight': 2064, 'arrivaldelaymins': 12969, 'numofdelays': 431, 'delaypercentage': 20}
# {'weight': 3441, 'arrivaldelaymins': 29378, 'numofdelays': 768, 'delaypercentage': 22}
# {'weight': 93, 'arrivaldelaymins': 1526, 'numofdelays': 33, 'delaypercentage': 35}
# {'weight': 642, 'arrivaldelaymins': 4844, 'numofdelays': 136, 'delaypercentage': 21}
# {'weight': 1352, 'arrivaldelaymins': 12389, 'numofdelays': 302, 'delaypercentage': 22}
# {'weight': 2866, 'arrivaldelaymins': 32944, 'numofdelays': 733, 'delaypercentage': 25}
# {'weight': 2450, 'arrivaldelaymins': 20174, 'numofdelays': 519, 'delaypercentage': 21}
# {'weight': 964, 'arrivaldelaymins': 7925, 'numofdelays': 185, 'delaypercentage': 19}
# {'weight': 2, 'arrivaldelaymins': 68, 'numofdelays': 2, 'delaypercentage': 100}
# {'weight': 107, 'arrivaldelaymins': 1048, 'numofdelays': 29, 'delaypercentage': 27}
# {'weight': 836, 'arrivaldelaymins': 12837, 'numofdelays': 234, 'delaypercentage': 27}
# {'weight': 637, 'arrivaldelaymins': 10537, 'numofdelays': 218, 'delaypercentage': 34}
# {'weight': 3593, 'arrivaldelaymins': 29645, 'numofdelays': 809, 'delaypercentage': 22}
# {'weight': 2155, 'arrivaldelaymins': 18564, 'numofdelays': 448, 'delaypercentage': 20}
# {'weight': 2627, 'arrivaldelaymins': 22527, 'numofdelays': 565, 'delaypercentage': 21}
# {'weight': 5309, 'arrivaldelaymins': 51395, 'numofdelays': 1154, 'delaypercentage': 21}
# {'weight': 5268, 'arrivaldelaymins': 49620, 'numofdelays': 1210, 'delaypercentage': 22}
# {'weight': 3146, 'arrivaldelaymins': 35746, 'numofdelays': 789, 'delaypercentage': 25}
# {'weight': 1996, 'arrivaldelaymins': 22235, 'numofdelays': 488, 'delaypercentage': 24}
# {'weight': 3517, 'arrivaldelaymins': 35735, 'numofdelays': 810, 'delaypercentage': 23}
# {'weight': 214, 'arrivaldelaymins': 2652, 'numofdelays': 55, 'delaypercentage': 25}
# {'weight': 118, 'arrivaldelaymins': 1430, 'numofdelays': 30, 'delaypercentage': 25}
# {'weight': 2694, 'arrivaldelaymins': 31101, 'numofdelays': 654, 'delaypercentage': 24}
# {'weight': 5656, 'arrivaldelaymins': 39892, 'numofdelays': 1065, 'delaypercentage': 18}
# {'weight': 1915, 'arrivaldelaymins': 36203, 'numofdelays': 722, 'delaypercentage': 37}
# {'weight': 4766, 'arrivaldelaymins': 55509, 'numofdelays': 1432, 'delaypercentage': 30}
# {'weight': 544, 'arrivaldelaymins': 1990, 'numofdelays': 106, 'delaypercentage': 19}
# {'weight': 5406, 'arrivaldelaymins': 76299, 'numofdelays': 1802, 'delaypercentage': 33}
# {'weight': 2213, 'arrivaldelaymins': 16522, 'numofdelays': 503, 'delaypercentage': 22}
# {'weight': 995, 'arrivaldelaymins': 9508, 'numofdelays': 224, 'delaypercentage': 22}
# {'weight': 10506, 'arrivaldelaymins': 171890, 'numofdelays': 3387, 'delaypercentage': 32}
# {'weight': 2527, 'arrivaldelaymins': 29140, 'numofdelays': 641, 'delaypercentage': 25}
# {'weight': 185, 'arrivaldelaymins': 654, 'numofdelays': 26, 'delaypercentage': 14}
# {'weight': 625, 'arrivaldelaymins': 3638, 'numofdelays': 126, 'delaypercentage': 20}
# {'weight': 4140, 'arrivaldelaymins': 41173, 'numofdelays': 928, 'delaypercentage': 22}
# {'weight': 652, 'arrivaldelaymins': 8367, 'numofdelays': 158, 'delaypercentage': 24}
# {'weight': 9613, 'arrivaldelaymins': 97279, 'numofdelays': 2209, 'delaypercentage': 22}
# {'weight': 1789, 'arrivaldelaymins': 19811, 'numofdelays': 429, 'delaypercentage': 23}
# {'weight': 3256, 'arrivaldelaymins': 39619, 'numofdelays': 834, 'delaypercentage': 25}
# {'weight': 674, 'arrivaldelaymins': 4212, 'numofdelays': 118, 'delaypercentage': 17}
# {'weight': 4866, 'arrivaldelaymins': 47725, 'numofdelays': 1047, 'delaypercentage': 21}
# {'weight': 9, 'arrivaldelaymins': 31, 'numofdelays': 3, 'delaypercentage': 33}
# {'weight': 2513, 'arrivaldelaymins': 20754, 'numofdelays': 533, 'delaypercentage': 21}
# {'weight': 695, 'arrivaldelaymins': 13477, 'numofdelays': 235, 'delaypercentage': 33}
# {'weight': 6628, 'arrivaldelaymins': 60753, 'numofdelays': 1443, 'delaypercentage': 21}
# {'weight': 3610, 'arrivaldelaymins': 27395, 'numofdelays': 797, 'delaypercentage': 22}
# {'weight': 2000, 'arrivaldelaymins': 22935, 'numofdelays': 508, 'delaypercentage': 25}
# {'weight': 2590, 'arrivaldelaymins': 25628, 'numofdelays': 634, 'delaypercentage': 24}
# {'weight': 983, 'arrivaldelaymins': 9176, 'numofdelays': 231, 'delaypercentage': 23}
# {'weight': 2224, 'arrivaldelaymins': 20471, 'numofdelays': 514, 'delaypercentage': 23}
# {'weight': 384, 'arrivaldelaymins': 3425, 'numofdelays': 89, 'delaypercentage': 23}
# {'weight': 5368, 'arrivaldelaymins': 42011, 'numofdelays': 1228, 'delaypercentage': 22}
# {'weight': 4695, 'arrivaldelaymins': 38221, 'numofdelays': 985, 'delaypercentage': 20}
# {'weight': 37, 'arrivaldelaymins': 378, 'numofdelays': 11, 'delaypercentage': 29}
# {'weight': 1853, 'arrivaldelaymins': 29144, 'numofdelays': 551, 'delaypercentage': 29}
# {'weight': 1178, 'arrivaldelaymins': 11268, 'numofdelays': 260, 'delaypercentage': 22}
# {'weight': 90, 'arrivaldelaymins': 1292, 'numofdelays': 26, 'delaypercentage': 28}
# {'weight': 1883, 'arrivaldelaymins': 25593, 'numofdelays': 551, 'delaypercentage': 29}
# {'weight': 1730, 'arrivaldelaymins': 22978, 'numofdelays': 485, 'delaypercentage': 28}
# {'weight': 796, 'arrivaldelaymins': 9184, 'numofdelays': 236, 'delaypercentage': 29}
# {'weight': 7677, 'arrivaldelaymins': 128699, 'numofdelays': 2196, 'delaypercentage': 28}
# {'weight': 2784, 'arrivaldelaymins': 30341, 'numofdelays': 688, 'delaypercentage': 24}
# {'weight': 4263, 'arrivaldelaymins': 45700, 'numofdelays': 1059, 'delaypercentage': 24}
# {'weight': 1095, 'arrivaldelaymins': 11145, 'numofdelays': 292, 'delaypercentage': 26}
# {'weight': 2548, 'arrivaldelaymins': 34703, 'numofdelays': 672, 'delaypercentage': 26}
# {'weight': 4158, 'arrivaldelaymins': 37881, 'numofdelays': 874, 'delaypercentage': 21}
# {'weight': 6915, 'arrivaldelaymins': 77986, 'numofdelays': 1729, 'delaypercentage': 25}
# {'weight': 4603, 'arrivaldelaymins': 41423, 'numofdelays': 1202, 'delaypercentage': 26}
# {'weight': 622, 'arrivaldelaymins': 7226, 'numofdelays': 161, 'delaypercentage': 25}
# {'weight': 4555, 'arrivaldelaymins': 39042, 'numofdelays': 986, 'delaypercentage': 21}
# {'weight': 4429, 'arrivaldelaymins': 42796, 'numofdelays': 953, 'delaypercentage': 21}
# {'weight': 1389, 'arrivaldelaymins': 19058, 'numofdelays': 399, 'delaypercentage': 28}
# {'weight': 904, 'arrivaldelaymins': 12678, 'numofdelays': 277, 'delaypercentage': 30}
# {'weight': 5411, 'arrivaldelaymins': 45743, 'numofdelays': 1114, 'delaypercentage': 20}
# {'weight': 4532, 'arrivaldelaymins': 36743, 'numofdelays': 886, 'delaypercentage': 19}
# {'weight': 167, 'arrivaldelaymins': 3486, 'numofdelays': 54, 'delaypercentage': 32}
# {'weight': 1732, 'arrivaldelaymins': 10100, 'numofdelays': 329, 'delaypercentage': 18}
# {'weight': 2489, 'arrivaldelaymins': 25829, 'numofdelays': 618, 'delaypercentage': 24}
# {'weight': 4193, 'arrivaldelaymins': 35065, 'numofdelays': 843, 'delaypercentage': 20}
# {'weight': 2857, 'arrivaldelaymins': 31605, 'numofdelays': 862, 'delaypercentage': 30}
# {'weight': 3239, 'arrivaldelaymins': 42621, 'numofdelays': 893, 'delaypercentage': 27}
# {'weight': 3892, 'arrivaldelaymins': 30349, 'numofdelays': 746, 'delaypercentage': 19}
# {'weight': 1038, 'arrivaldelaymins': 8158, 'numofdelays': 238, 'delaypercentage': 22}
# {'weight': 121, 'arrivaldelaymins': 234, 'numofdelays': 20, 'delaypercentage': 16}
# {'weight': 2754, 'arrivaldelaymins': 30362, 'numofdelays': 683, 'delaypercentage': 24}
# {'weight': 2574, 'arrivaldelaymins': 21815, 'numofdelays': 701, 'delaypercentage': 27}
# {'weight': 3462, 'arrivaldelaymins': 44958, 'numofdelays': 1111, 'delaypercentage': 32}
# {'weight': 1171, 'arrivaldelaymins': 7703, 'numofdelays': 249, 'delaypercentage': 21}
# {'weight': 1816, 'arrivaldelaymins': 20077, 'numofdelays': 425, 'delaypercentage': 23}
# {'weight': 640, 'arrivaldelaymins': 8546, 'numofdelays': 217, 'delaypercentage': 33}
# {'weight': 1874, 'arrivaldelaymins': 12849, 'numofdelays': 396, 'delaypercentage': 21}
# {'weight': 2860, 'arrivaldelaymins': 32903, 'numofdelays': 808, 'delaypercentage': 28}
# {'weight': 682, 'arrivaldelaymins': 8488, 'numofdelays': 210, 'delaypercentage': 30}
# {'weight': 1461, 'arrivaldelaymins': 10864, 'numofdelays': 369, 'delaypercentage': 25}
# {'weight': 3326, 'arrivaldelaymins': 37435, 'numofdelays': 769, 'delaypercentage': 23}
# {'weight': 3958, 'arrivaldelaymins': 41675, 'numofdelays': 967, 'delaypercentage': 24}
# {'weight': 451, 'arrivaldelaymins': 2751, 'numofdelays': 87, 'delaypercentage': 19}
# {'weight': 67, 'arrivaldelaymins': 1308, 'numofdelays': 30, 'delaypercentage': 44}
# {'weight': 1617, 'arrivaldelaymins': 14634, 'numofdelays': 374, 'delaypercentage': 23}
# {'weight': 1419, 'arrivaldelaymins': 19605, 'numofdelays': 397, 'delaypercentage': 27}
# {'weight': 2484, 'arrivaldelaymins': 27710, 'numofdelays': 585, 'delaypercentage': 23}
# {'weight': 119, 'arrivaldelaymins': 54, 'numofdelays': 21, 'delaypercentage': 17}
# {'weight': 7311, 'arrivaldelaymins': 70773, 'numofdelays': 1574, 'delaypercentage': 21}
# {'weight': 1809, 'arrivaldelaymins': 13642, 'numofdelays': 376, 'delaypercentage': 20}
# {'weight': 1981, 'arrivaldelaymins': 27122, 'numofdelays': 547, 'delaypercentage': 27}
# {'weight': 668, 'arrivaldelaymins': 8838, 'numofdelays': 225, 'delaypercentage': 33}
# {'weight': 2428, 'arrivaldelaymins': 24469, 'numofdelays': 565, 'delaypercentage': 23}
# {'weight': 938, 'arrivaldelaymins': 9399, 'numofdelays': 226, 'delaypercentage': 24}
# {'weight': 3046, 'arrivaldelaymins': 50863, 'numofdelays': 923, 'delaypercentage': 30}
# {'weight': 1769, 'arrivaldelaymins': 16892, 'numofdelays': 408, 'delaypercentage': 23}
# {'weight': 743, 'arrivaldelaymins': 8078, 'numofdelays': 191, 'delaypercentage': 25}
# {'weight': 697, 'arrivaldelaymins': 6187, 'numofdelays': 152, 'delaypercentage': 21}
# {'weight': 1, 'arrivaldelaymins': 210, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 1020, 'arrivaldelaymins': -101, 'numofdelays': 131, 'delaypercentage': 12}
# {'weight': 1032, 'arrivaldelaymins': 2068, 'numofdelays': 132, 'delaypercentage': 12}
# {'weight': 90, 'arrivaldelaymins': 690, 'numofdelays': 15, 'delaypercentage': 16}
# {'weight': 2288, 'arrivaldelaymins': 33798, 'numofdelays': 572, 'delaypercentage': 25}
# {'weight': 435, 'arrivaldelaymins': 1493, 'numofdelays': 61, 'delaypercentage': 14}
# {'weight': 2252, 'arrivaldelaymins': 31474, 'numofdelays': 596, 'delaypercentage': 26}
# {'weight': 792, 'arrivaldelaymins': 1506, 'numofdelays': 104, 'delaypercentage': 13}
# {'weight': 368, 'arrivaldelaymins': 1504, 'numofdelays': 65, 'delaypercentage': 17}
# {'weight': 730, 'arrivaldelaymins': -120, 'numofdelays': 86, 'delaypercentage': 11}
# {'weight': 380, 'arrivaldelaymins': 1922, 'numofdelays': 63, 'delaypercentage': 16}
# {'weight': 659, 'arrivaldelaymins': 3298, 'numofdelays': 109, 'delaypercentage': 16}
# {'weight': 653, 'arrivaldelaymins': 4082, 'numofdelays': 114, 'delaypercentage': 17}
# {'weight': 5573, 'arrivaldelaymins': 33131, 'numofdelays': 825, 'delaypercentage': 14}
# {'weight': 2673, 'arrivaldelaymins': 14495, 'numofdelays': 435, 'delaypercentage': 16}
# {'weight': 5506, 'arrivaldelaymins': 35884, 'numofdelays': 962, 'delaypercentage': 17}
# {'weight': 1, 'arrivaldelaymins': 100, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 1349, 'arrivaldelaymins': 7085, 'numofdelays': 216, 'delaypercentage': 16}
# {'weight': 949, 'arrivaldelaymins': 12840, 'numofdelays': 281, 'delaypercentage': 29}
# {'weight': 481, 'arrivaldelaymins': -2402, 'numofdelays': 38, 'delaypercentage': 7}
# {'weight': 2319, 'arrivaldelaymins': 16992, 'numofdelays': 383, 'delaypercentage': 16}
# {'weight': 367, 'arrivaldelaymins': 1743, 'numofdelays': 55, 'delaypercentage': 14}
# {'weight': 670, 'arrivaldelaymins': 7182, 'numofdelays': 144, 'delaypercentage': 21}
# {'weight': 3691, 'arrivaldelaymins': 25879, 'numofdelays': 619, 'delaypercentage': 16}
# {'weight': 218, 'arrivaldelaymins': -1857, 'numofdelays': 18, 'delaypercentage': 8}
# {'weight': 226, 'arrivaldelaymins': 2253, 'numofdelays': 51, 'delaypercentage': 22}
# {'weight': 1358, 'arrivaldelaymins': 13116, 'numofdelays': 385, 'delaypercentage': 28}
# {'weight': 1231, 'arrivaldelaymins': 3410, 'numofdelays': 189, 'delaypercentage': 15}
# {'weight': 1733, 'arrivaldelaymins': 7184, 'numofdelays': 288, 'delaypercentage': 16}
# {'weight': 692, 'arrivaldelaymins': 4426, 'numofdelays': 108, 'delaypercentage': 15}
# {'weight': 245, 'arrivaldelaymins': 2968, 'numofdelays': 60, 'delaypercentage': 24}
# {'weight': 470, 'arrivaldelaymins': 2714, 'numofdelays': 79, 'delaypercentage': 16}
# {'weight': 459, 'arrivaldelaymins': 2311, 'numofdelays': 64, 'delaypercentage': 13}
# {'weight': 632, 'arrivaldelaymins': 2111, 'numofdelays': 92, 'delaypercentage': 14}
# {'weight': 712, 'arrivaldelaymins': 1448, 'numofdelays': 105, 'delaypercentage': 14}
# {'weight': 834, 'arrivaldelaymins': 2332, 'numofdelays': 103, 'delaypercentage': 12}
# {'weight': 55, 'arrivaldelaymins': 874, 'numofdelays': 13, 'delaypercentage': 23}
# {'weight': 444, 'arrivaldelaymins': 3247, 'numofdelays': 76, 'delaypercentage': 17}
# {'weight': 236, 'arrivaldelaymins': 2502, 'numofdelays': 63, 'delaypercentage': 26}
# {'weight': 88, 'arrivaldelaymins': 785, 'numofdelays': 28, 'delaypercentage': 31}
# {'weight': 305, 'arrivaldelaymins': 2355, 'numofdelays': 55, 'delaypercentage': 18}
# {'weight': 2514, 'arrivaldelaymins': 27068, 'numofdelays': 569, 'delaypercentage': 22}
# {'weight': 290, 'arrivaldelaymins': -3362, 'numofdelays': 24, 'delaypercentage': 8}
# {'weight': 2783, 'arrivaldelaymins': 9841, 'numofdelays': 408, 'delaypercentage': 14}
# {'weight': 231, 'arrivaldelaymins': 294, 'numofdelays': 31, 'delaypercentage': 13}
# {'weight': 719, 'arrivaldelaymins': 1907, 'numofdelays': 119, 'delaypercentage': 16}
# {'weight': 149, 'arrivaldelaymins': 1345, 'numofdelays': 40, 'delaypercentage': 26}
# {'weight': 610, 'arrivaldelaymins': 4765, 'numofdelays': 115, 'delaypercentage': 18}
# {'weight': 968, 'arrivaldelaymins': 3163, 'numofdelays': 151, 'delaypercentage': 15}
# {'weight': 548, 'arrivaldelaymins': -3342, 'numofdelays': 34, 'delaypercentage': 6}
# {'weight': 245, 'arrivaldelaymins': 142, 'numofdelays': 21, 'delaypercentage': 8}
# {'weight': 95, 'arrivaldelaymins': 544, 'numofdelays': 15, 'delaypercentage': 15}
# {'weight': 367, 'arrivaldelaymins': 2459, 'numofdelays': 74, 'delaypercentage': 20}
# {'weight': 88, 'arrivaldelaymins': -316, 'numofdelays': 7, 'delaypercentage': 7}
# {'weight': 228, 'arrivaldelaymins': -205, 'numofdelays': 29, 'delaypercentage': 12}
# {'weight': 1936, 'arrivaldelaymins': 14271, 'numofdelays': 341, 'delaypercentage': 17}
# {'weight': 167, 'arrivaldelaymins': -630, 'numofdelays': 13, 'delaypercentage': 7}
# {'weight': 768, 'arrivaldelaymins': 228, 'numofdelays': 107, 'delaypercentage': 13}
# {'weight': 658, 'arrivaldelaymins': 16655, 'numofdelays': 264, 'delaypercentage': 40}
# {'weight': 459, 'arrivaldelaymins': 3938, 'numofdelays': 95, 'delaypercentage': 20}
# {'weight': 47, 'arrivaldelaymins': -132, 'numofdelays': 7, 'delaypercentage': 14}
# {'weight': 364, 'arrivaldelaymins': -256, 'numofdelays': 39, 'delaypercentage': 10}
# {'weight': 586, 'arrivaldelaymins': 7018, 'numofdelays': 160, 'delaypercentage': 27}
# {'weight': 356, 'arrivaldelaymins': -898, 'numofdelays': 36, 'delaypercentage': 10}
# {'weight': 722, 'arrivaldelaymins': 3358, 'numofdelays': 108, 'delaypercentage': 14}
# {'weight': 3, 'arrivaldelaymins': 239, 'numofdelays': 3, 'delaypercentage': 100}
# {'weight': 716, 'arrivaldelaymins': 16295, 'numofdelays': 220, 'delaypercentage': 30}
# {'weight': 148, 'arrivaldelaymins': -1214, 'numofdelays': 10, 'delaypercentage': 6}
# {'weight': 1177, 'arrivaldelaymins': 3605, 'numofdelays': 169, 'delaypercentage': 14}
# {'weight': 1, 'arrivaldelaymins': 36, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 245, 'arrivaldelaymins': 152, 'numofdelays': 29, 'delaypercentage': 11}
# {'weight': 2352, 'arrivaldelaymins': 26248, 'numofdelays': 520, 'delaypercentage': 22}
# {'weight': 1, 'arrivaldelaymins': 80, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 2141, 'arrivaldelaymins': 23070, 'numofdelays': 536, 'delaypercentage': 25}
# {'weight': 366, 'arrivaldelaymins': 2675, 'numofdelays': 70, 'delaypercentage': 19}
# {'weight': 2880, 'arrivaldelaymins': 16206, 'numofdelays': 427, 'delaypercentage': 14}
# {'weight': 544, 'arrivaldelaymins': 1594, 'numofdelays': 101, 'delaypercentage': 18}
# {'weight': 1834, 'arrivaldelaymins': 7515, 'numofdelays': 326, 'delaypercentage': 17}
# {'weight': 1187, 'arrivaldelaymins': 3701, 'numofdelays': 181, 'delaypercentage': 15}
# {'weight': 1182, 'arrivaldelaymins': -11393, 'numofdelays': 65, 'delaypercentage': 5}
# {'weight': 214, 'arrivaldelaymins': 1047, 'numofdelays': 46, 'delaypercentage': 21}
# {'weight': 1065, 'arrivaldelaymins': 14376, 'numofdelays': 332, 'delaypercentage': 31}
# {'weight': 1516, 'arrivaldelaymins': 5451, 'numofdelays': 245, 'delaypercentage': 16}
# {'weight': 766, 'arrivaldelaymins': 14385, 'numofdelays': 244, 'delaypercentage': 31}
# {'weight': 546, 'arrivaldelaymins': 7034, 'numofdelays': 157, 'delaypercentage': 28}
# {'weight': 1397, 'arrivaldelaymins': 11477, 'numofdelays': 280, 'delaypercentage': 20}
# {'weight': 120, 'arrivaldelaymins': -203, 'numofdelays': 12, 'delaypercentage': 10}
# {'weight': 585, 'arrivaldelaymins': -552, 'numofdelays': 69, 'delaypercentage': 11}
# {'weight': 602, 'arrivaldelaymins': 5816, 'numofdelays': 139, 'delaypercentage': 23}
# {'weight': 366, 'arrivaldelaymins': -2912, 'numofdelays': 45, 'delaypercentage': 12}
# {'weight': 132, 'arrivaldelaymins': 3176, 'numofdelays': 54, 'delaypercentage': 40}
# {'weight': 1755, 'arrivaldelaymins': 3785, 'numofdelays': 288, 'delaypercentage': 16}
# {'weight': 1028, 'arrivaldelaymins': 292, 'numofdelays': 156, 'delaypercentage': 15}
# {'weight': 48, 'arrivaldelaymins': -267, 'numofdelays': 3, 'delaypercentage': 6}
# {'weight': 366, 'arrivaldelaymins': 2240, 'numofdelays': 72, 'delaypercentage': 19}
# {'weight': 536, 'arrivaldelaymins': 3773, 'numofdelays': 104, 'delaypercentage': 19}
# {'weight': 986, 'arrivaldelaymins': 1503, 'numofdelays': 157, 'delaypercentage': 15}
# {'weight': 3131, 'arrivaldelaymins': 33669, 'numofdelays': 759, 'delaypercentage': 24}
# {'weight': 373, 'arrivaldelaymins': 2787, 'numofdelays': 68, 'delaypercentage': 18}
# {'weight': 521, 'arrivaldelaymins': 3877, 'numofdelays': 106, 'delaypercentage': 20}
# {'weight': 335, 'arrivaldelaymins': -605, 'numofdelays': 63, 'delaypercentage': 18}
# {'weight': 1150, 'arrivaldelaymins': 5440, 'numofdelays': 199, 'delaypercentage': 17}
# {'weight': 134, 'arrivaldelaymins': 1597, 'numofdelays': 43, 'delaypercentage': 32}
# {'weight': 366, 'arrivaldelaymins': 4756, 'numofdelays': 75, 'delaypercentage': 20}
# {'weight': 1276, 'arrivaldelaymins': 6933, 'numofdelays': 241, 'delaypercentage': 18}
# {'weight': 1035, 'arrivaldelaymins': 5761, 'numofdelays': 201, 'delaypercentage': 19}
# {'weight': 533, 'arrivaldelaymins': 3401, 'numofdelays': 97, 'delaypercentage': 18}
# {'weight': 102, 'arrivaldelaymins': 1413, 'numofdelays': 20, 'delaypercentage': 19}
# {'weight': 906, 'arrivaldelaymins': -1944, 'numofdelays': 72, 'delaypercentage': 7}
# {'weight': 1194, 'arrivaldelaymins': -2423, 'numofdelays': 108, 'delaypercentage': 9}
# {'weight': 225, 'arrivaldelaymins': -149, 'numofdelays': 21, 'delaypercentage': 9}
# {'weight': 943, 'arrivaldelaymins': 9261, 'numofdelays': 191, 'delaypercentage': 20}
# {'weight': 371, 'arrivaldelaymins': -3927, 'numofdelays': 15, 'delaypercentage': 4}
# {'weight': 227, 'arrivaldelaymins': -2528, 'numofdelays': 5, 'delaypercentage': 2}
# {'weight': 728, 'arrivaldelaymins': 3267, 'numofdelays': 108, 'delaypercentage': 14}
# {'weight': 270, 'arrivaldelaymins': 5944, 'numofdelays': 98, 'delaypercentage': 36}
# {'weight': 793, 'arrivaldelaymins': 5938, 'numofdelays': 167, 'delaypercentage': 21}
# {'weight': 1, 'arrivaldelaymins': 70, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 129, 'arrivaldelaymins': 1231, 'numofdelays': 33, 'delaypercentage': 25}
# {'weight': 801, 'arrivaldelaymins': 3075, 'numofdelays': 132, 'delaypercentage': 16}
# {'weight': 536, 'arrivaldelaymins': 13453, 'numofdelays': 207, 'delaypercentage': 38}
# {'weight': 338, 'arrivaldelaymins': 5549, 'numofdelays': 105, 'delaypercentage': 31}
# {'weight': 11, 'arrivaldelaymins': 60, 'numofdelays': 2, 'delaypercentage': 18}
# {'weight': 2876, 'arrivaldelaymins': 25660, 'numofdelays': 587, 'delaypercentage': 20}
# {'weight': 1, 'arrivaldelaymins': 36, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 696, 'arrivaldelaymins': 2724, 'numofdelays': 83, 'delaypercentage': 11}
# {'weight': 1038, 'arrivaldelaymins': 6280, 'numofdelays': 170, 'delaypercentage': 16}
# {'weight': 264, 'arrivaldelaymins': 248, 'numofdelays': 37, 'delaypercentage': 14}
# {'weight': 786, 'arrivaldelaymins': 5930, 'numofdelays': 172, 'delaypercentage': 21}
# {'weight': 598, 'arrivaldelaymins': 3365, 'numofdelays': 104, 'delaypercentage': 17}
# {'weight': 1074, 'arrivaldelaymins': 4994, 'numofdelays': 160, 'delaypercentage': 14}
# {'weight': 666, 'arrivaldelaymins': 7851, 'numofdelays': 182, 'delaypercentage': 27}
# {'weight': 1287, 'arrivaldelaymins': 11081, 'numofdelays': 256, 'delaypercentage': 19}
# {'weight': 892, 'arrivaldelaymins': 1497, 'numofdelays': 141, 'delaypercentage': 15}
# {'weight': 668, 'arrivaldelaymins': 13354, 'numofdelays': 207, 'delaypercentage': 30}
# {'weight': 723, 'arrivaldelaymins': 4540, 'numofdelays': 131, 'delaypercentage': 18}
# {'weight': 245, 'arrivaldelaymins': 2858, 'numofdelays': 62, 'delaypercentage': 25}
# {'weight': 2345, 'arrivaldelaymins': 15434, 'numofdelays': 418, 'delaypercentage': 17}
# {'weight': 366, 'arrivaldelaymins': 2000, 'numofdelays': 65, 'delaypercentage': 17}
# {'weight': 1, 'arrivaldelaymins': 252, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 366, 'arrivaldelaymins': 755, 'numofdelays': 58, 'delaypercentage': 15}
# {'weight': 840, 'arrivaldelaymins': 9079, 'numofdelays': 243, 'delaypercentage': 28}
# {'weight': 1196, 'arrivaldelaymins': 1644, 'numofdelays': 127, 'delaypercentage': 10}
# {'weight': 709, 'arrivaldelaymins': 1667, 'numofdelays': 87, 'delaypercentage': 12}
# {'weight': 886, 'arrivaldelaymins': 2720, 'numofdelays': 136, 'delaypercentage': 15}
# {'weight': 1008, 'arrivaldelaymins': 8209, 'numofdelays': 178, 'delaypercentage': 17}
# {'weight': 1497, 'arrivaldelaymins': 45361, 'numofdelays': 598, 'delaypercentage': 39}
# {'weight': 366, 'arrivaldelaymins': -1956, 'numofdelays': 42, 'delaypercentage': 11}
# {'weight': 159, 'arrivaldelaymins': -1102, 'numofdelays': 9, 'delaypercentage': 5}
# {'weight': 679, 'arrivaldelaymins': 3866, 'numofdelays': 103, 'delaypercentage': 15}
# {'weight': 8, 'arrivaldelaymins': 465, 'numofdelays': 7, 'delaypercentage': 87}
# {'weight': 366, 'arrivaldelaymins': 72, 'numofdelays': 27, 'delaypercentage': 7}
# {'weight': 1071, 'arrivaldelaymins': 10639, 'numofdelays': 230, 'delaypercentage': 21}
# {'weight': 1628, 'arrivaldelaymins': 4713, 'numofdelays': 222, 'delaypercentage': 13}
# {'weight': 820, 'arrivaldelaymins': -1661, 'numofdelays': 56, 'delaypercentage': 6}
# {'weight': 103, 'arrivaldelaymins': 1290, 'numofdelays': 29, 'delaypercentage': 28}
# {'weight': 1950, 'arrivaldelaymins': -4089, 'numofdelays': 143, 'delaypercentage': 7}
# {'weight': 1239, 'arrivaldelaymins': 3481, 'numofdelays': 182, 'delaypercentage': 14}
# {'weight': 1052, 'arrivaldelaymins': 3718, 'numofdelays': 156, 'delaypercentage': 14}
# {'weight': 74, 'arrivaldelaymins': -268, 'numofdelays': 6, 'delaypercentage': 8}
# {'weight': 120, 'arrivaldelaymins': -1433, 'numofdelays': 4, 'delaypercentage': 3}
# {'weight': 2511, 'arrivaldelaymins': 23988, 'numofdelays': 571, 'delaypercentage': 22}
# {'weight': 60, 'arrivaldelaymins': 1621, 'numofdelays': 23, 'delaypercentage': 38}
# {'weight': 50, 'arrivaldelaymins': -181, 'numofdelays': 2, 'delaypercentage': 4}
# {'weight': 173, 'arrivaldelaymins': 1153, 'numofdelays': 29, 'delaypercentage': 16}
# {'weight': 2007, 'arrivaldelaymins': 25810, 'numofdelays': 457, 'delaypercentage': 22}
# {'weight': 3097, 'arrivaldelaymins': 29946, 'numofdelays': 665, 'delaypercentage': 21}
# {'weight': 795, 'arrivaldelaymins': 10914, 'numofdelays': 207, 'delaypercentage': 26}
# {'weight': 365, 'arrivaldelaymins': 2281, 'numofdelays': 78, 'delaypercentage': 21}
# {'weight': 688, 'arrivaldelaymins': 6005, 'numofdelays': 128, 'delaypercentage': 18}
# {'weight': 78, 'arrivaldelaymins': 1443, 'numofdelays': 32, 'delaypercentage': 41}
# {'weight': 2502, 'arrivaldelaymins': 8943, 'numofdelays': 411, 'delaypercentage': 16}
# {'weight': 1, 'arrivaldelaymins': 18, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 1147, 'arrivaldelaymins': 8894, 'numofdelays': 226, 'delaypercentage': 19}
# {'weight': 2127, 'arrivaldelaymins': 329, 'numofdelays': 242, 'delaypercentage': 11}
# {'weight': 677, 'arrivaldelaymins': 4414, 'numofdelays': 133, 'delaypercentage': 19}
# {'weight': 769, 'arrivaldelaymins': 1265, 'numofdelays': 98, 'delaypercentage': 12}
# {'weight': 1403, 'arrivaldelaymins': 6584, 'numofdelays': 228, 'delaypercentage': 16}
# {'weight': 2529, 'arrivaldelaymins': 16937, 'numofdelays': 527, 'delaypercentage': 20}
# {'weight': 2859, 'arrivaldelaymins': 17278, 'numofdelays': 464, 'delaypercentage': 16}
# {'weight': 2708, 'arrivaldelaymins': 15624, 'numofdelays': 461, 'delaypercentage': 17}
# {'weight': 1836, 'arrivaldelaymins': 32261, 'numofdelays': 564, 'delaypercentage': 30}
# {'weight': 738, 'arrivaldelaymins': 5939, 'numofdelays': 163, 'delaypercentage': 22}
# {'weight': 2, 'arrivaldelaymins': 35, 'numofdelays': 1, 'delaypercentage': 50}
# {'weight': 1504, 'arrivaldelaymins': 10450, 'numofdelays': 304, 'delaypercentage': 20}
# {'weight': 418, 'arrivaldelaymins': 8292, 'numofdelays': 144, 'delaypercentage': 34}
# {'weight': 2522, 'arrivaldelaymins': 14206, 'numofdelays': 441, 'delaypercentage': 17}
# {'weight': 1382, 'arrivaldelaymins': 11844, 'numofdelays': 270, 'delaypercentage': 19}
# {'weight': 523, 'arrivaldelaymins': 4052, 'numofdelays': 103, 'delaypercentage': 19}
# {'weight': 1202, 'arrivaldelaymins': 2134, 'numofdelays': 220, 'delaypercentage': 18}
# {'weight': 1400, 'arrivaldelaymins': 9384, 'numofdelays': 327, 'delaypercentage': 23}
# {'weight': 1216, 'arrivaldelaymins': 19642, 'numofdelays': 399, 'delaypercentage': 32}
# {'weight': 1302, 'arrivaldelaymins': 10250, 'numofdelays': 251, 'delaypercentage': 19}
# {'weight': 1798, 'arrivaldelaymins': 8183, 'numofdelays': 309, 'delaypercentage': 17}
# {'weight': 2993, 'arrivaldelaymins': 23672, 'numofdelays': 519, 'delaypercentage': 17}
# {'weight': 1020, 'arrivaldelaymins': 5955, 'numofdelays': 162, 'delaypercentage': 15}
# {'weight': 731, 'arrivaldelaymins': 2036, 'numofdelays': 86, 'delaypercentage': 11}
# {'weight': 772, 'arrivaldelaymins': 5353, 'numofdelays': 132, 'delaypercentage': 17}
# {'weight': 785, 'arrivaldelaymins': 1532, 'numofdelays': 113, 'delaypercentage': 14}
# {'weight': 1012, 'arrivaldelaymins': 7090, 'numofdelays': 190, 'delaypercentage': 18}
# {'weight': 363, 'arrivaldelaymins': 2438, 'numofdelays': 102, 'delaypercentage': 28}
# {'weight': 365, 'arrivaldelaymins': 2792, 'numofdelays': 98, 'delaypercentage': 26}
# {'weight': 3725, 'arrivaldelaymins': 63571, 'numofdelays': 1089, 'delaypercentage': 29}
# {'weight': 236, 'arrivaldelaymins': -819, 'numofdelays': 41, 'delaypercentage': 17}
# {'weight': 980, 'arrivaldelaymins': 10791, 'numofdelays': 246, 'delaypercentage': 25}
# {'weight': 1124, 'arrivaldelaymins': 2556, 'numofdelays': 209, 'delaypercentage': 18}
# {'weight': 366, 'arrivaldelaymins': 3196, 'numofdelays': 78, 'delaypercentage': 21}
# {'weight': 1623, 'arrivaldelaymins': 13085, 'numofdelays': 348, 'delaypercentage': 21}
# {'weight': 721, 'arrivaldelaymins': 1104, 'numofdelays': 140, 'delaypercentage': 19}
# {'weight': 677, 'arrivaldelaymins': 4930, 'numofdelays': 158, 'delaypercentage': 23}
# {'weight': 364, 'arrivaldelaymins': 3537, 'numofdelays': 104, 'delaypercentage': 28}
# {'weight': 115, 'arrivaldelaymins': 1023, 'numofdelays': 28, 'delaypercentage': 24}
# {'weight': 258, 'arrivaldelaymins': 1018, 'numofdelays': 41, 'delaypercentage': 15}
# {'weight': 1720, 'arrivaldelaymins': 8550, 'numofdelays': 296, 'delaypercentage': 17}
# {'weight': 41, 'arrivaldelaymins': -351, 'numofdelays': 1, 'delaypercentage': 2}
# {'weight': 2064, 'arrivaldelaymins': 5974, 'numofdelays': 310, 'delaypercentage': 15}
# {'weight': 1042, 'arrivaldelaymins': 5518, 'numofdelays': 169, 'delaypercentage': 16}
# {'weight': 756, 'arrivaldelaymins': -121, 'numofdelays': 83, 'delaypercentage': 10}
# {'weight': 1001, 'arrivaldelaymins': 5354, 'numofdelays': 186, 'delaypercentage': 18}
# {'weight': 807, 'arrivaldelaymins': 4294, 'numofdelays': 127, 'delaypercentage': 15}
# {'weight': 666, 'arrivaldelaymins': -938, 'numofdelays': 62, 'delaypercentage': 9}
# {'weight': 471, 'arrivaldelaymins': 2771, 'numofdelays': 74, 'delaypercentage': 15}
# {'weight': 787, 'arrivaldelaymins': 10557, 'numofdelays': 177, 'delaypercentage': 22}
# {'weight': 1027, 'arrivaldelaymins': 2951, 'numofdelays': 130, 'delaypercentage': 12}
# {'weight': 679, 'arrivaldelaymins': -1709, 'numofdelays': 60, 'delaypercentage': 8}
# {'weight': 1, 'arrivaldelaymins': 29, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 1029, 'arrivaldelaymins': 2683, 'numofdelays': 132, 'delaypercentage': 12}
# {'weight': 475, 'arrivaldelaymins': 5089, 'numofdelays': 105, 'delaypercentage': 22}
# {'weight': 1080, 'arrivaldelaymins': 3698, 'numofdelays': 160, 'delaypercentage': 14}
# {'weight': 1754, 'arrivaldelaymins': 25348, 'numofdelays': 454, 'delaypercentage': 25}
# {'weight': 3342, 'arrivaldelaymins': 2665, 'numofdelays': 311, 'delaypercentage': 9}
# {'weight': 1, 'arrivaldelaymins': 35, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 5982, 'arrivaldelaymins': 59467, 'numofdelays': 1398, 'delaypercentage': 23}
# {'weight': 368, 'arrivaldelaymins': 444, 'numofdelays': 71, 'delaypercentage': 19}
# {'weight': 794, 'arrivaldelaymins': 11332, 'numofdelays': 208, 'delaypercentage': 26}
# {'weight': 2, 'arrivaldelaymins': 64, 'numofdelays': 2, 'delaypercentage': 100}
# {'weight': 729, 'arrivaldelaymins': 9623, 'numofdelays': 174, 'delaypercentage': 23}
# {'weight': 4797, 'arrivaldelaymins': 39107, 'numofdelays': 946, 'delaypercentage': 19}
# {'weight': 467, 'arrivaldelaymins': 6187, 'numofdelays': 115, 'delaypercentage': 24}
# {'weight': 156, 'arrivaldelaymins': 1076, 'numofdelays': 27, 'delaypercentage': 17}
# {'weight': 1362, 'arrivaldelaymins': 11896, 'numofdelays': 251, 'delaypercentage': 18}
# {'weight': 3533, 'arrivaldelaymins': 20255, 'numofdelays': 734, 'delaypercentage': 20}
# {'weight': 916, 'arrivaldelaymins': 9956, 'numofdelays': 242, 'delaypercentage': 26}
# {'weight': 1937, 'arrivaldelaymins': 11333, 'numofdelays': 331, 'delaypercentage': 17}
# {'weight': 8899, 'arrivaldelaymins': 1995, 'numofdelays': 1215, 'delaypercentage': 13}
# {'weight': 2077, 'arrivaldelaymins': 23389, 'numofdelays': 567, 'delaypercentage': 27}
# {'weight': 3036, 'arrivaldelaymins': 13703, 'numofdelays': 634, 'delaypercentage': 20}
# {'weight': 2306, 'arrivaldelaymins': 17322, 'numofdelays': 428, 'delaypercentage': 18}
# {'weight': 3883, 'arrivaldelaymins': 103197, 'numofdelays': 1460, 'delaypercentage': 37}
# {'weight': 2476, 'arrivaldelaymins': 32331, 'numofdelays': 700, 'delaypercentage': 28}
# {'weight': 141, 'arrivaldelaymins': 2977, 'numofdelays': 60, 'delaypercentage': 42}
# {'weight': 4184, 'arrivaldelaymins': 42139, 'numofdelays': 862, 'delaypercentage': 20}
# {'weight': 1800, 'arrivaldelaymins': 22904, 'numofdelays': 494, 'delaypercentage': 27}
# {'weight': 950, 'arrivaldelaymins': 6029, 'numofdelays': 181, 'delaypercentage': 19}
# {'weight': 647, 'arrivaldelaymins': 7885, 'numofdelays': 169, 'delaypercentage': 26}
# {'weight': 7372, 'arrivaldelaymins': 124054, 'numofdelays': 2164, 'delaypercentage': 29}
# {'weight': 1383, 'arrivaldelaymins': 2648, 'numofdelays': 306, 'delaypercentage': 22}
# {'weight': 2234, 'arrivaldelaymins': 28167, 'numofdelays': 713, 'delaypercentage': 31}
# {'weight': 12029, 'arrivaldelaymins': 59969, 'numofdelays': 2308, 'delaypercentage': 19}
# {'weight': 788, 'arrivaldelaymins': 8247, 'numofdelays': 203, 'delaypercentage': 25}
# ...
# {'weight': 301, 'arrivaldelaymins': -1715, 'numofdelays': 28, 'delaypercentage': 9}
# {'weight': 120, 'arrivaldelaymins': 1595, 'numofdelays': 25, 'delaypercentage': 20}
# {'weight': 21, 'arrivaldelaymins': -206, 'numofdelays': 1, 'delaypercentage': 4}
# {'weight': 1337, 'arrivaldelaymins': 7412, 'numofdelays': 254, 'delaypercentage': 18}
# {'weight': 366, 'arrivaldelaymins': 2760, 'numofdelays': 87, 'delaypercentage': 23}
# {'weight': 391, 'arrivaldelaymins': 2147, 'numofdelays': 87, 'delaypercentage': 22}
# {'weight': 7313, 'arrivaldelaymins': 60073, 'numofdelays': 1309, 'delaypercentage': 17}
# {'weight': 367, 'arrivaldelaymins': 402, 'numofdelays': 38, 'delaypercentage': 10}
# {'weight': 1266, 'arrivaldelaymins': 9992, 'numofdelays': 261, 'delaypercentage': 20}
# {'weight': 1052, 'arrivaldelaymins': 3926, 'numofdelays': 141, 'delaypercentage': 13}
# {'weight': 1695, 'arrivaldelaymins': 11292, 'numofdelays': 289, 'delaypercentage': 17}
# {'weight': 1782, 'arrivaldelaymins': 18911, 'numofdelays': 418, 'delaypercentage': 23}
# {'weight': 728, 'arrivaldelaymins': 1706, 'numofdelays': 111, 'delaypercentage': 15}
# {'weight': 3402, 'arrivaldelaymins': 21335, 'numofdelays': 611, 'delaypercentage': 17}
# {'weight': 359, 'arrivaldelaymins': 35, 'numofdelays': 33, 'delaypercentage': 9}
# {'weight': 874, 'arrivaldelaymins': -827, 'numofdelays': 89, 'delaypercentage': 10}
# {'weight': 2825, 'arrivaldelaymins': -2142, 'numofdelays': 301, 'delaypercentage': 10}
# {'weight': 973, 'arrivaldelaymins': 5492, 'numofdelays': 168, 'delaypercentage': 17}
# {'weight': 1101, 'arrivaldelaymins': 8703, 'numofdelays': 182, 'delaypercentage': 16}
# {'weight': 204, 'arrivaldelaymins': 2204, 'numofdelays': 48, 'delaypercentage': 23}
# {'weight': 1554, 'arrivaldelaymins': -3463, 'numofdelays': 157, 'delaypercentage': 10}
# {'weight': 1692, 'arrivaldelaymins': 9423, 'numofdelays': 344, 'delaypercentage': 20}
# {'weight': 2804, 'arrivaldelaymins': 21209, 'numofdelays': 597, 'delaypercentage': 21}
# {'weight': 1452, 'arrivaldelaymins': 889, 'numofdelays': 214, 'delaypercentage': 14}
# {'weight': 2837, 'arrivaldelaymins': 50855, 'numofdelays': 946, 'delaypercentage': 33}
# {'weight': 3051, 'arrivaldelaymins': 17511, 'numofdelays': 520, 'delaypercentage': 17}
# {'weight': 200, 'arrivaldelaymins': 955, 'numofdelays': 24, 'delaypercentage': 12}
# {'weight': 366, 'arrivaldelaymins': 1233, 'numofdelays': 49, 'delaypercentage': 13}
# {'weight': 1411, 'arrivaldelaymins': 7026, 'numofdelays': 283, 'delaypercentage': 20}
# {'weight': 60, 'arrivaldelaymins': 542, 'numofdelays': 13, 'delaypercentage': 21}
# {'weight': 1906, 'arrivaldelaymins': 8317, 'numofdelays': 338, 'delaypercentage': 17}
# {'weight': 1962, 'arrivaldelaymins': 10001, 'numofdelays': 295, 'delaypercentage': 15}
# {'weight': 1578, 'arrivaldelaymins': 8667, 'numofdelays': 238, 'delaypercentage': 15}
# {'weight': 1093, 'arrivaldelaymins': 4005, 'numofdelays': 205, 'delaypercentage': 18}
# {'weight': 1006, 'arrivaldelaymins': 3882, 'numofdelays': 127, 'delaypercentage': 12}
# {'weight': 3395, 'arrivaldelaymins': 33993, 'numofdelays': 760, 'delaypercentage': 22}
# {'weight': 1178, 'arrivaldelaymins': 1370, 'numofdelays': 178, 'delaypercentage': 15}
# {'weight': 519, 'arrivaldelaymins': 1708, 'numofdelays': 93, 'delaypercentage': 17}
# {'weight': 1465, 'arrivaldelaymins': 27587, 'numofdelays': 510, 'delaypercentage': 34}
# {'weight': 699, 'arrivaldelaymins': 1612, 'numofdelays': 131, 'delaypercentage': 18}
# {'weight': 1, 'arrivaldelaymins': 126, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 2218, 'arrivaldelaymins': 8097, 'numofdelays': 334, 'delaypercentage': 15}
# {'weight': 860, 'arrivaldelaymins': 709, 'numofdelays': 113, 'delaypercentage': 13}
# {'weight': 741, 'arrivaldelaymins': 3527, 'numofdelays': 134, 'delaypercentage': 18}
# {'weight': 1829, 'arrivaldelaymins': 18410, 'numofdelays': 369, 'delaypercentage': 20}
# {'weight': 178, 'arrivaldelaymins': 2903, 'numofdelays': 65, 'delaypercentage': 36}
# {'weight': 1005, 'arrivaldelaymins': 5877, 'numofdelays': 165, 'delaypercentage': 16}
# {'weight': 1088, 'arrivaldelaymins': 6253, 'numofdelays': 183, 'delaypercentage': 16}
# {'weight': 2288, 'arrivaldelaymins': 31339, 'numofdelays': 569, 'delaypercentage': 24}
# {'weight': 366, 'arrivaldelaymins': -478, 'numofdelays': 38, 'delaypercentage': 10}
# {'weight': 1353, 'arrivaldelaymins': 10664, 'numofdelays': 265, 'delaypercentage': 19}
# {'weight': 95, 'arrivaldelaymins': 204, 'numofdelays': 15, 'delaypercentage': 15}
# {'weight': 3380, 'arrivaldelaymins': 24606, 'numofdelays': 687, 'delaypercentage': 20}
# {'weight': 1022, 'arrivaldelaymins': 4699, 'numofdelays': 213, 'delaypercentage': 20}
# {'weight': 1096, 'arrivaldelaymins': 935, 'numofdelays': 132, 'delaypercentage': 12}
# {'weight': 136, 'arrivaldelaymins': -540, 'numofdelays': 17, 'delaypercentage': 12}
# {'weight': 981, 'arrivaldelaymins': 3092, 'numofdelays': 156, 'delaypercentage': 15}
# {'weight': 1067, 'arrivaldelaymins': 1874, 'numofdelays': 140, 'delaypercentage': 13}
# {'weight': 366, 'arrivaldelaymins': 2153, 'numofdelays': 62, 'delaypercentage': 16}
# {'weight': 365, 'arrivaldelaymins': 2365, 'numofdelays': 72, 'delaypercentage': 19}
# {'weight': 488, 'arrivaldelaymins': 736, 'numofdelays': 59, 'delaypercentage': 12}
# {'weight': 366, 'arrivaldelaymins': 548, 'numofdelays': 22, 'delaypercentage': 6}
# {'weight': 329, 'arrivaldelaymins': 575, 'numofdelays': 44, 'delaypercentage': 13}
# {'weight': 1099, 'arrivaldelaymins': 6682, 'numofdelays': 221, 'delaypercentage': 20}
# {'weight': 235, 'arrivaldelaymins': -184, 'numofdelays': 26, 'delaypercentage': 11}
# {'weight': 301, 'arrivaldelaymins': -1991, 'numofdelays': 20, 'delaypercentage': 6}
# {'weight': 1808, 'arrivaldelaymins': 7510, 'numofdelays': 317, 'delaypercentage': 17}
# {'weight': 16, 'arrivaldelaymins': 239, 'numofdelays': 7, 'delaypercentage': 43}
# {'weight': 249, 'arrivaldelaymins': -691, 'numofdelays': 25, 'delaypercentage': 10}
# {'weight': 44, 'arrivaldelaymins': 552, 'numofdelays': 11, 'delaypercentage': 25}
# {'weight': 229, 'arrivaldelaymins': 560, 'numofdelays': 19, 'delaypercentage': 8}
# {'weight': 1, 'arrivaldelaymins': 61, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 1980, 'arrivaldelaymins': 19981, 'numofdelays': 414, 'delaypercentage': 20}
# {'weight': 90, 'arrivaldelaymins': -111, 'numofdelays': 7, 'delaypercentage': 7}
# {'weight': 883, 'arrivaldelaymins': 4455, 'numofdelays': 135, 'delaypercentage': 15}
# {'weight': 2284, 'arrivaldelaymins': 14978, 'numofdelays': 365, 'delaypercentage': 15}
# {'weight': 1631, 'arrivaldelaymins': 8741, 'numofdelays': 274, 'delaypercentage': 16}
# {'weight': 3260, 'arrivaldelaymins': 20291, 'numofdelays': 566, 'delaypercentage': 17}
# {'weight': 726, 'arrivaldelaymins': 4626, 'numofdelays': 121, 'delaypercentage': 16}
# {'weight': 344, 'arrivaldelaymins': 1594, 'numofdelays': 35, 'delaypercentage': 10}
# {'weight': 1300, 'arrivaldelaymins': 7693, 'numofdelays': 252, 'delaypercentage': 19}
# {'weight': 2319, 'arrivaldelaymins': 11474, 'numofdelays': 319, 'delaypercentage': 13}
# {'weight': 391, 'arrivaldelaymins': 296, 'numofdelays': 57, 'delaypercentage': 14}
# {'weight': 73, 'arrivaldelaymins': -23, 'numofdelays': 6, 'delaypercentage': 8}
# {'weight': 806, 'arrivaldelaymins': 4554, 'numofdelays': 131, 'delaypercentage': 16}
# {'weight': 1094, 'arrivaldelaymins': 9262, 'numofdelays': 231, 'delaypercentage': 21}
# {'weight': 717, 'arrivaldelaymins': 1864, 'numofdelays': 115, 'delaypercentage': 16}
# {'weight': 1, 'arrivaldelaymins': 92, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 227, 'arrivaldelaymins': 1025, 'numofdelays': 44, 'delaypercentage': 19}
# {'weight': 2038, 'arrivaldelaymins': 29015, 'numofdelays': 509, 'delaypercentage': 24}
# {'weight': 1021, 'arrivaldelaymins': -771, 'numofdelays': 125, 'delaypercentage': 12}
# {'weight': 228, 'arrivaldelaymins': 1427, 'numofdelays': 66, 'delaypercentage': 28}
# {'weight': 88, 'arrivaldelaymins': -159, 'numofdelays': 6, 'delaypercentage': 6}
# {'weight': 599, 'arrivaldelaymins': 3600, 'numofdelays': 81, 'delaypercentage': 13}
# {'weight': 225, 'arrivaldelaymins': 300, 'numofdelays': 35, 'delaypercentage': 15}
# {'weight': 890, 'arrivaldelaymins': 3804, 'numofdelays': 116, 'delaypercentage': 13}
# {'weight': 10, 'arrivaldelaymins': -18, 'numofdelays': 1, 'delaypercentage': 10}
# {'weight': 718, 'arrivaldelaymins': 2182, 'numofdelays': 86, 'delaypercentage': 11}
# {'weight': 667, 'arrivaldelaymins': 4451, 'numofdelays': 135, 'delaypercentage': 20}
# {'weight': 229, 'arrivaldelaymins': 2543, 'numofdelays': 50, 'delaypercentage': 21}
# {'weight': 207, 'arrivaldelaymins': 754, 'numofdelays': 29, 'delaypercentage': 14}
# {'weight': 2029, 'arrivaldelaymins': 1230, 'numofdelays': 240, 'delaypercentage': 11}
# {'weight': 2676, 'arrivaldelaymins': 14393, 'numofdelays': 392, 'delaypercentage': 14}
# {'weight': 88, 'arrivaldelaymins': -228, 'numofdelays': 7, 'delaypercentage': 7}
# {'weight': 186, 'arrivaldelaymins': 1839, 'numofdelays': 49, 'delaypercentage': 26}
# {'weight': 151, 'arrivaldelaymins': -496, 'numofdelays': 19, 'delaypercentage': 12}
# {'weight': 112, 'arrivaldelaymins': -934, 'numofdelays': 8, 'delaypercentage': 7}
# {'weight': 1669, 'arrivaldelaymins': 9324, 'numofdelays': 239, 'delaypercentage': 14}
# {'weight': 132, 'arrivaldelaymins': 478, 'numofdelays': 25, 'delaypercentage': 18}
# {'weight': 2242, 'arrivaldelaymins': 16937, 'numofdelays': 392, 'delaypercentage': 17}
# {'weight': 4190, 'arrivaldelaymins': 6177, 'numofdelays': 523, 'delaypercentage': 12}
# {'weight': 230, 'arrivaldelaymins': 932, 'numofdelays': 31, 'delaypercentage': 13}
# {'weight': 723, 'arrivaldelaymins': -3944, 'numofdelays': 45, 'delaypercentage': 6}
# {'weight': 439, 'arrivaldelaymins': 582, 'numofdelays': 62, 'delaypercentage': 14}
# {'weight': 306, 'arrivaldelaymins': -5150, 'numofdelays': 8, 'delaypercentage': 2}
# {'weight': 221, 'arrivaldelaymins': -465, 'numofdelays': 26, 'delaypercentage': 11}
# {'weight': 477, 'arrivaldelaymins': 3162, 'numofdelays': 61, 'delaypercentage': 12}
# {'weight': 865, 'arrivaldelaymins': 8942, 'numofdelays': 221, 'delaypercentage': 25}
# {'weight': 3474, 'arrivaldelaymins': 18222, 'numofdelays': 555, 'delaypercentage': 15}
# {'weight': 219, 'arrivaldelaymins': -69, 'numofdelays': 24, 'delaypercentage': 10}
# {'weight': 1412, 'arrivaldelaymins': 11081, 'numofdelays': 247, 'delaypercentage': 17}
# {'weight': 239, 'arrivaldelaymins': 569, 'numofdelays': 31, 'delaypercentage': 12}
# {'weight': 444, 'arrivaldelaymins': 1142, 'numofdelays': 86, 'delaypercentage': 19}
# {'weight': 365, 'arrivaldelaymins': 22, 'numofdelays': 38, 'delaypercentage': 10}
# {'weight': 1485, 'arrivaldelaymins': 1351, 'numofdelays': 125, 'delaypercentage': 8}
# {'weight': 465, 'arrivaldelaymins': 302, 'numofdelays': 75, 'delaypercentage': 16}
# {'weight': 129, 'arrivaldelaymins': -37, 'numofdelays': 18, 'delaypercentage': 13}
# {'weight': 89, 'arrivaldelaymins': 785, 'numofdelays': 21, 'delaypercentage': 23}
# {'weight': 1210, 'arrivaldelaymins': 4101, 'numofdelays': 174, 'delaypercentage': 14}
# {'weight': 50, 'arrivaldelaymins': 1145, 'numofdelays': 11, 'delaypercentage': 22}
# {'weight': 1, 'arrivaldelaymins': 54, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 347, 'arrivaldelaymins': 815, 'numofdelays': 44, 'delaypercentage': 12}
# {'weight': 2436, 'arrivaldelaymins': 36860, 'numofdelays': 608, 'delaypercentage': 24}
# {'weight': 1810, 'arrivaldelaymins': -4517, 'numofdelays': 185, 'delaypercentage': 10}
# {'weight': 1250, 'arrivaldelaymins': 7014, 'numofdelays': 173, 'delaypercentage': 13}
# {'weight': 1585, 'arrivaldelaymins': 5345, 'numofdelays': 191, 'delaypercentage': 12}
# {'weight': 2431, 'arrivaldelaymins': 26395, 'numofdelays': 574, 'delaypercentage': 23}
# {'weight': 3, 'arrivaldelaymins': 294, 'numofdelays': 3, 'delaypercentage': 100}
# {'weight': 511, 'arrivaldelaymins': 3688, 'numofdelays': 90, 'delaypercentage': 17}
# {'weight': 954, 'arrivaldelaymins': 5824, 'numofdelays': 144, 'delaypercentage': 15}
# {'weight': 511, 'arrivaldelaymins': 1451, 'numofdelays': 76, 'delaypercentage': 14}
# {'weight': 1506, 'arrivaldelaymins': 12464, 'numofdelays': 319, 'delaypercentage': 21}
# {'weight': 1424, 'arrivaldelaymins': 2768, 'numofdelays': 187, 'delaypercentage': 13}
# {'weight': 651, 'arrivaldelaymins': 17030, 'numofdelays': 217, 'delaypercentage': 33}
# {'weight': 96, 'arrivaldelaymins': 423, 'numofdelays': 21, 'delaypercentage': 21}
# {'weight': 1344, 'arrivaldelaymins': 5806, 'numofdelays': 241, 'delaypercentage': 17}
# {'weight': 603, 'arrivaldelaymins': 6956, 'numofdelays': 161, 'delaypercentage': 26}
# {'weight': 125, 'arrivaldelaymins': 25, 'numofdelays': 18, 'delaypercentage': 14}
# {'weight': 1460, 'arrivaldelaymins': 8677, 'numofdelays': 227, 'delaypercentage': 15}
# {'weight': 365, 'arrivaldelaymins': 1740, 'numofdelays': 51, 'delaypercentage': 13}
# {'weight': 2019, 'arrivaldelaymins': 19248, 'numofdelays': 453, 'delaypercentage': 22}
# {'weight': 938, 'arrivaldelaymins': 10926, 'numofdelays': 188, 'delaypercentage': 20}
# {'weight': 3045, 'arrivaldelaymins': 46255, 'numofdelays': 833, 'delaypercentage': 27}
# {'weight': 103, 'arrivaldelaymins': -271, 'numofdelays': 7, 'delaypercentage': 6}
# {'weight': 1968, 'arrivaldelaymins': 13817, 'numofdelays': 310, 'delaypercentage': 15}
# {'weight': 421, 'arrivaldelaymins': 3985, 'numofdelays': 69, 'delaypercentage': 16}
# {'weight': 2, 'arrivaldelaymins': 68, 'numofdelays': 1, 'delaypercentage': 50}
# {'weight': 1045, 'arrivaldelaymins': 3986, 'numofdelays': 92, 'delaypercentage': 8}
# {'weight': 236, 'arrivaldelaymins': 6150, 'numofdelays': 81, 'delaypercentage': 34}
# {'weight': 363, 'arrivaldelaymins': 594, 'numofdelays': 63, 'delaypercentage': 17}
# {'weight': 364, 'arrivaldelaymins': 2530, 'numofdelays': 76, 'delaypercentage': 20}
# {'weight': 264, 'arrivaldelaymins': -2937, 'numofdelays': 3, 'delaypercentage': 1}
# {'weight': 1768, 'arrivaldelaymins': 14444, 'numofdelays': 348, 'delaypercentage': 19}
# {'weight': 1, 'arrivaldelaymins': 54, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 101, 'arrivaldelaymins': -678, 'numofdelays': 5, 'delaypercentage': 4}
# {'weight': 209, 'arrivaldelaymins': 822, 'numofdelays': 41, 'delaypercentage': 19}
# {'weight': 685, 'arrivaldelaymins': 3177, 'numofdelays': 116, 'delaypercentage': 16}
# {'weight': 2781, 'arrivaldelaymins': 26836, 'numofdelays': 540, 'delaypercentage': 19}
# {'weight': 361, 'arrivaldelaymins': -138, 'numofdelays': 49, 'delaypercentage': 13}
# {'weight': 545, 'arrivaldelaymins': 10321, 'numofdelays': 195, 'delaypercentage': 35}
# {'weight': 1, 'arrivaldelaymins': 25, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 1435, 'arrivaldelaymins': 19805, 'numofdelays': 301, 'delaypercentage': 20}
# {'weight': 358, 'arrivaldelaymins': 3974, 'numofdelays': 102, 'delaypercentage': 28}
# {'weight': 1, 'arrivaldelaymins': 59, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 766, 'arrivaldelaymins': 11916, 'numofdelays': 241, 'delaypercentage': 31}
# {'weight': 1044, 'arrivaldelaymins': 8077, 'numofdelays': 180, 'delaypercentage': 17}
# {'weight': 154, 'arrivaldelaymins': 1593, 'numofdelays': 37, 'delaypercentage': 24}
# {'weight': 676, 'arrivaldelaymins': 829, 'numofdelays': 72, 'delaypercentage': 10}
# {'weight': 3114, 'arrivaldelaymins': 47102, 'numofdelays': 817, 'delaypercentage': 26}
# {'weight': 104, 'arrivaldelaymins': 2143, 'numofdelays': 27, 'delaypercentage': 25}
# {'weight': 1, 'arrivaldelaymins': 70, 'numofdelays': 1, 'delaypercentage': 100}
# {'weight': 363, 'arrivaldelaymins': 2861, 'numofdelays': 78, 'delaypercentage': 21}
# {'weight': 362, 'arrivaldelaymins': 1153, 'numofdelays': 75, 'delaypercentage': 20}
# {'weight': 340, 'arrivaldelaymins': 1835, 'numofdelays': 67, 'delaypercentage': 19}
# {'weight': 326, 'arrivaldelaymins': 312, 'numofdelays': 31, 'delaypercentage': 9}
# {'weight': 99, 'arrivaldelaymins': 629, 'numofdelays': 17, 'delaypercentage': 17}
# {'weight': 1044, 'arrivaldelaymins': 2566, 'numofdelays': 107, 'delaypercentage': 10}
# {'weight': 1961, 'arrivaldelaymins': 9379, 'numofdelays': 243, 'delaypercentage': 12}
# {'weight': 440, 'arrivaldelaymins': -50, 'numofdelays': 39, 'delaypercentage': 8}

# %%
# write to CSV?
import csv

with open('exports/airportList.csv', 'w') as csvfile:
    fieldnames = ['iata', 'name','long','lat','totalflights','numberofdelays',
                  'delaypercentage','carrierdelay','weatherdelay','nasdelay','securitydelay',
                 'lateaircraftdelay','betweenness','outdegree','indegree']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    # loop through node list 
    for airport, attr in G.nodes(data=True):
        writer.writerow({'iata': airport, 'name': attr['name'], 'long': attr['long'],'lat': attr['lat'], 
                         'totalflights': attr['totalflights'],'numberofdelays': attr['numberofdelays'],
                         'delaypercentage': attr['delaypercentage'],'carrierdelay': attr['carrierdelay'],
                         'weatherdelay': attr['weatherdelay'],'nasdelay': attr['nasdelay'],
                         'securitydelay': attr['securitydelay'],'lateaircraftdelay': attr['lateaircraftdelay'],
                         'betweenness': attr['betweenness'],'outdegree': attr['outdegree'],
                         'indegree': attr['indegree']
                        })

# %%
# edge list  

def getLat(code):
    temp = (airports.loc[airports.iata==code,"latitude"].values[0])
    return temp

def getLong(code):
    temp = (airports.loc[airports.iata==code,"longitude"].values[0])
    return temp

with open('exports/edgeList.csv', 'w') as csvfile:
    fieldnames = ['origin','originlat','originlong',
                  'destination','destinationlat','destinationlong',
                  'weight','arrivaldelaymins','numofdelays','delaypercentage']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    # loop through edge list 
    for origin,destination,attr in G.edges_iter(data=True):
        # get the origin lat/long
        # get the destination lat/long
        olat = getLat(origin)
        olng = getLong(origin)
        dlat = getLat(destination)
        dlng = getLong(destination)
        writer.writerow({'origin': origin,'originlat': olat, "originlong": olng,
                         'destination':destination,'destinationlat': dlat, "destinationlong": dlng,
                         'weight': attr['weight'], 'arrivaldelaymins': attr['arrivaldelaymins'], 
                         'numofdelays': attr['numofdelays'],'delaypercentage': attr['delaypercentage']
                        })

# %%
# write to a graphml file
nx.write_graphml(G, "flightsOverviewDelays.graphml")

# %%
# release 
G = None
